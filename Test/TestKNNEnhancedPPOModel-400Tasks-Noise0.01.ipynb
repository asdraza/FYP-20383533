# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    X = data.drop(columns=['Eligible'])
    y = data['Eligible']
    return X, y

def optimize_knn_model(X_train, y_train):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    knn_model = KNeighborsRegressor()
    param_grid = {
        'n_neighbors': [3, 5, 10, 20, 30, 40],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan'],
        'p': [1, 2]  # 1: Manhattan distance, 2: Euclidean distance
    }
    grid_search = GridSearchCV(knn_model, param_grid, cv=5, verbose=1, scoring='neg_mean_squared_error')
    grid_search.fit(X_train_scaled, y_train)
    print("Best parameters:", grid_search.best_params_)
    best_knn = grid_search.best_estimator_
    return best_knn, scaler

# Load and train on VehicleTrainingDataset.csv
X_train, y_train = load_and_preprocess_data('VehicleTrainingDataset_Noisy_0.01.csv')
knn_model, scaler = optimize_knn_model(X_train, y_train)

# Predict eligibility scores on 1000VehicleDataset.csv
vehicles_df = pd.read_csv('1000VehicleDataset_Noisy_0.01.csv')
X_test = vehicles_df.drop(columns=['Eligible'])
X_test_scaled = scaler.transform(X_test)
predicted_scores = knn_model.predict(X_test_scaled)

# Assuming you have access to actual scores, replace this line with the actual score loading logic if available
y_actual = vehicles_df['Eligible']

# Replace actual scores with predicted ones
vehicles_df['Eligible'] = predicted_scores  

# Calculate metrics
mae = mean_absolute_error(y_actual, predicted_scores)
rmse = np.sqrt(mean_squared_error(y_actual, predicted_scores))
r_squared = r2_score(y_actual, predicted_scores)
rae = np.sum(np.abs(y_actual - predicted_scores)) / np.sum(np.abs(y_actual - np.mean(y_actual)))

# Output the results
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R-squared: {r_squared}")
print(f"RAE: {rae}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# MAE: 1.7258836094021666
# RMSE: 2.159748576425794
# R-squared: 0.9684512036561819
# RAE: 0.18025169439477964

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -386.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.083333333333334
# All assignments history: [22, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    fps             | 117      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -288.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.458333333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -374         |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0076119294 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.87        |
# |    explained_variance   | 0.0534       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 3.63         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0403      |
# |    value_loss           | 17           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.083333333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 3            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0073273284 |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | -0.0217      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.43         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0395      |
# |    value_loss           | 13           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -398.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.354166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006617973 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.061      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.84        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -340.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.2
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 5            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0066706897 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | -0.0283      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.54         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0338      |
# |    value_loss           | 10           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -284.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 6           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007523004 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | 0.00378     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.5         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 8.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.25
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 7           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008028955 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.00597    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.29        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 7.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.197916666666664
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 8            |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0088626435 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.83        |
# |    explained_variance   | 0.00766      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.37         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0404      |
# |    value_loss           | 5.73         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.57407407407408
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 9           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008664668 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.00373     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.61        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 5.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.55833333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 10          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010334663 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.00272     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 4.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.96212121212122
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 11          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.011436559 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00402     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.5625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 12          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010561418 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00297     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.789       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.8076923076923
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 13          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012432726 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00248     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.173       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0491     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 107.39285714285714
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 14          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014859766 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00238     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0255     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.52222222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 15          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.014602455 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00494     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.173      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.16145833333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 16          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013238654 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0133      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.465       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.96078431372548
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 17          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010144807 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.41666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 18          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008912407 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.117       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 132.31578947368422
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 19          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.010342135 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.122       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.99583333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 20          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008892825 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0628     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.40873015873015
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 21          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009116189 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.546       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.49621212121212
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -355         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 22           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0075778924 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.97         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0381      |
# |    value_loss           | 2.91         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.3985507246377
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -353         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 23           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0082695875 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.35         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0448      |
# |    value_loss           | 2.79         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.06597222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 24          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007450371 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.862       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.52
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 25          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.006973339 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.372       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.76282051282053
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 26          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008419933 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.01234567901236
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 27          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007795007 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.16964285714286
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 28          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008037323 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.839       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.2528735632184
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 29          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008581683 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.491       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.2
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 30          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008016793 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.11021505376345
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 31          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008212917 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 3.42        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.94010416666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 32          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008831795 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.461       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.6818181818182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 33          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008554544 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.681       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.38725490196077
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 34          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008871328 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.528       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0506     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.05714285714285
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 35          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008541154 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.563       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.7337962962963
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -320        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 36          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008662111 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.02        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.30180180180182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -317        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 37          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.008729973 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.26        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.8815789473684
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 38          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008459631 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.965       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 130.0
# Standard deviation of reward: 0.0
# Average successful assignments: 176.55982905982907
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -310         |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 39           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0079889055 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0.43         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.664        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0481      |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.2
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 40          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008256853 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.787       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.8028455284553
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -302        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 41          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008251619 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.736       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0489     |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 181.41666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -298        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 42          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008836921 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0467     |
# |    value_loss           | 3.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 183.00968992248062
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -295        |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 43          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009246857 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.872       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 184.5681818181818
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 44          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007952789 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.881       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 186.10555555555555
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 45          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.009544192 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 440         |
# ...
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -56.5        |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 86           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0076238057 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.28         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0358      |
# |    value_loss           | 3.34         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.4434865900383
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -51.9        |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 87           |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0077686706 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.35         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0355      |
# |    value_loss           | 3.13         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -47.9       |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 88          |
# |    time_elapsed         | 550         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006243974 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.56179775280899
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -44.6        |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 89           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0076428284 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.35         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0338      |
# |    value_loss           | 3.56         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.1212962962963
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -41.3       |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 90          |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006051955 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.59        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 3.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.6831501831502
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -38.5        |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 91           |
# |    time_elapsed         | 562          |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0069335103 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.09         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0364      |
# |    value_loss           | 3.25         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 227.231884057971
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.8        |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 92           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0072397534 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0377      |
# |    value_loss           | 3.3          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 184.0
# Standard deviation of reward: 0.0
# Average successful assignments: 227.79301075268816
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -31.1       |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 93          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006814676 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 3.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 228.29255319148936
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -28.6        |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 94           |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0061071385 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.24         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0351      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 228.7938596491228
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -25.8        |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 95           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0060417634 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.35         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0361      |
# |    value_loss           | 3.37         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 229.27256944444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -23.1       |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 96          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006885356 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 229.75601374570448
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -20.9        |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 97           |
# |    time_elapsed         | 583          |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0062600644 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.48         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0325      |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 230.22619047619048
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -18.9        |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 98           |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0069248946 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.24         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0366      |
# |    value_loss           | 3.47         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 230.6885521885522
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 99          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.006659029 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.74        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 231.15083333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 100         |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007325705 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.38        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 102.98
# Overall Average Successful Assignments: 173.84874018440797

# %%
# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks400Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 172.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 286.0
