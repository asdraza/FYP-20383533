# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    X = data.drop(columns=['Eligible'])
    y = data['Eligible']
    return X, y

def optimize_knn_model(X_train, y_train):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    knn_model = KNeighborsRegressor()
    param_grid = {
        'n_neighbors': [3, 5, 10, 20, 30, 40],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan'],
        'p': [1, 2]  # 1: Manhattan distance, 2: Euclidean distance
    }
    grid_search = GridSearchCV(knn_model, param_grid, cv=5, verbose=1, scoring='neg_mean_squared_error')
    grid_search.fit(X_train_scaled, y_train)
    print("Best parameters:", grid_search.best_params_)
    best_knn = grid_search.best_estimator_
    return best_knn, scaler

# Load and train on VehicleTrainingDataset.csv
X_train, y_train = load_and_preprocess_data('VehicleTrainingDataset_Noisy_0.1.csv')
knn_model, scaler = optimize_knn_model(X_train, y_train)

# Predict eligibility scores on 1000VehicleDataset.csv
vehicles_df = pd.read_csv('1000VehicleDataset_Noisy_0.1.csv')
X_test = vehicles_df.drop(columns=['Eligible'])
X_test_scaled = scaler.transform(X_test)
predicted_scores = knn_model.predict(X_test_scaled)

# Assuming you have access to actual scores, replace this line with the actual score loading logic if available
y_actual = vehicles_df['Eligible']

# Replace actual scores with predicted ones
vehicles_df['Eligible'] = predicted_scores  

# Calculate metrics
mae = mean_absolute_error(y_actual, predicted_scores)
rmse = np.sqrt(mean_squared_error(y_actual, predicted_scores))
r_squared = r2_score(y_actual, predicted_scores)
rae = np.sum(np.abs(y_actual - predicted_scores)) / np.sum(np.abs(y_actual - np.mean(y_actual)))

# Output the results
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R-squared: {r_squared}")
print(f"RAE: {rae}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# MAE: 1.9645398393113325
# RMSE: 2.4344408047900314
# R-squared: 0.9599156505668087
# RAE: 0.20517700777318204

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -386.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.166666666666666
# All assignments history: [12, 16, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -372     |
# | time/              |          |
# |    fps             | 124      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.958333333333336
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0080727115 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.88        |
# |    explained_variance   | -0.117       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 3.37         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.041       |
# |    value_loss           | 18.7         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.97222222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008051347 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.0577     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.22        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.4375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 4           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008314097 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.91        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 10.4        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 102.46666666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 5            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0082042795 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.0256       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.22         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0392      |
# |    value_loss           | 8.9          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.76388888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 6           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008078171 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | 0.00688     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.89        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 8.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.80952380952381
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -369         |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 7            |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0075549795 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | 0.0254       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.96         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0355      |
# |    value_loss           | 7.44         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.54166666666666
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -368      |
# | time/                   |           |
# |    fps                  | 122       |
# |    iterations           | 8         |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0086885 |
# |    clip_fraction        | 0.156     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.84     |
# |    explained_variance   | 0.0112    |
# |    learning_rate        | 0.00018   |
# |    loss                 | 2.07      |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0397   |
# |    value_loss           | 5.7       |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.33333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 9           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008757135 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.62        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 5.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.26666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 10          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009776876 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.00869     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.84        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 4.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.8181818181818
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 11          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.011114218 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00928     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.583       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.10416666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 12          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011684401 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.167       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 3.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.60256410256412
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 13          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012678459 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.483       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.36904761904762
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -364       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 14         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01357184 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.78      |
# |    explained_variance   | 0.0124     |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.000151  |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0446    |
# |    value_loss           | 2.74       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.65555555555557
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 15          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.011491343 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0375      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.34375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 16          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011328274 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0839      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.031       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.0686274509804
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 17          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010222087 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.57        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.63888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 18          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009804014 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0619      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.07456140350877
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -358       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 19         |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 19456      |
# | train/                  |            |
# |    approx_kl            | 0.00836516 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.71      |
# |    explained_variance   | 0.196      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.56       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0381    |
# |    value_loss           | 3.06       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.29166666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 20          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009458574 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.46428571428572
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 21          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008627908 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.371       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.49242424242425
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 22          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008583782 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.92        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.46014492753622
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 23          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.008571899 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.49        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.33680555555554
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 24          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008409044 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.761       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.18
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -350         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 25           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0087379925 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.512        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0428      |
# |    value_loss           | 2.81         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.9647435897436
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 26          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007804395 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.868       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.7037037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 27          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008934909 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.43        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.42857142857142
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 28          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009059263 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.1867816091954
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 29          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.009202985 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.826       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.84166666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 30          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008765523 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.41        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.049      |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.44086021505376
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 31          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.009751406 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.68        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.11197916666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -333         |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 32           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0077633476 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.18         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0396      |
# |    value_loss           | 3.07         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.7348484848485
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 33          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008309435 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.931       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 3.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.3357843137255
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 34          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009134516 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0495     |
# |    value_loss           | 3.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.93333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 35          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009327507 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.55555555555554
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -321        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 36          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008858612 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.921       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0471     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.18693693693695
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -317        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 37          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.009801703 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 3.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.86622807017545
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 38          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010244651 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.54        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0501     |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.48931623931625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -310        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 39          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008846697 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.627       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.18333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -307        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 40          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008268762 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.24        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.91056910569105
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 41          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.009344794 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0497     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.63888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 42          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009419764 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.35658914728683
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 43          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.008848914 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 3.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.10037878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 44          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008889897 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.861       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.75925925925927
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 45          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.009213647 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.39        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 2.87        |
# ...
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 204.0125968992248
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 86           |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0069839135 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.4         |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.07         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0401      |
# |    value_loss           | 2.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 204.57183908045977
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 87          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.007537378 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 128.0
# Standard deviation of reward: 0.0
# Average successful assignments: 205.0880681818182
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -97.8        |
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 88           |
# |    time_elapsed         | 530          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0070309592 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.989        |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0396      |
# |    value_loss           | 2.84         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 205.62734082397003
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 89          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.010088137 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.982       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 206.13888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -92         |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 90          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007772947 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 206.66483516483515
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -89.5        |
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 91           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0074326145 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.35        |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.08         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0431      |
# |    value_loss           | 2.97         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.17934782608697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -86.8       |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 92          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008146664 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.05        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.6594982078853
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -84.4        |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 93           |
# |    time_elapsed         | 548          |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0064065754 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.34        |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.14         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.039       |
# |    value_loss           | 3.23         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 130.0
# Standard deviation of reward: 0.0
# Average successful assignments: 208.1285460992908
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -82.1       |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 94          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006527338 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.24        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 208.61140350877193
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -79.5        |
# | time/                   |              |
# |    fps                  | 175          |
# |    iterations           | 95           |
# |    time_elapsed         | 555          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0067217303 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.04         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.037       |
# |    value_loss           | 2.88         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 209.10069444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -77.3       |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 96          |
# |    time_elapsed         | 559         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007944011 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.34        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 3.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 209.58419243986253
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 97          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.007652539 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 210.03996598639455
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -73.1        |
# | time/                   |              |
# |    fps                  | 177          |
# |    iterations           | 98           |
# |    time_elapsed         | 566          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0063854028 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.83         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.036       |
# |    value_loss           | 3.33         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 210.50420875420875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -70.8       |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 99          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.007804486 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 210.9675
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -68.3      |
# | time/                   |            |
# |    fps                  | 178        |
# |    iterations           | 100        |
# |    time_elapsed         | 573        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00667933 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.22       |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0381    |
# |    value_loss           | 2.83       |
# ----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 60.66
# Overall Average Successful Assignments: 173.98298168735772

# %%
# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks400Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 136.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 268.0
