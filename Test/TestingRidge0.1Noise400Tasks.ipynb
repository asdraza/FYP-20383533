# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    X = data.drop(columns=['Eligible'])
    y = data['Eligible']
    return X, y

def train_ridge_model(X_train, y_train):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    ridge_model = Ridge()
    ridge_model.fit(X_train_scaled, y_train)
    return ridge_model, scaler

# Load and train on VehicleTrainingDataset.csv
X_train, y_train = load_and_preprocess_data('VehicleTrainingDataset_Noisy_0.1.csv')
ridge_model, scaler = train_ridge_model(X_train, y_train)

# Predict eligibility scores on 1000VehicleDataset.csv
vehicles_df = pd.read_csv('1000VehicleDataset_Noisy_0.1.csv')
X_test = vehicles_df.drop(columns=['Eligible'])
X_test_scaled = scaler.transform(X_test)
predicted_scores = ridge_model.predict(X_test_scaled)

# Assuming you have access to actual scores, replace this line with the actual score loading logic if available
y_actual = vehicles_df['Eligible']  # This would be prior to overwriting with predictions if you run this block again

# Replace actual scores with predicted ones
vehicles_df['Eligible'] = predicted_scores  

# Calculate metrics
mae = mean_absolute_error(y_actual, predicted_scores)
rmse = np.sqrt(mean_squared_error(y_actual, predicted_scores))
r_squared = r2_score(y_actual, predicted_scores)
rae = np.sum(np.abs(y_actual - predicted_scores)) / np.sum(np.abs(y_actual - np.mean(y_actual)))

# Output the results
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R-squared: {r_squared}")
print(f"RAE: {rae}")
# Out:
# MAE: 0.8967544998516832
# RMSE: 1.1358026956536529
# R-squared: 0.991274663358528
# RAE: 0.09365725311592739

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")


# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks400Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -378.0
# Standard deviation of reward: 0.0
# Average successful assignments: 11.75
# All assignments history: [16, 15, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -369     |
# | time/              |          |
# |    fps             | 211      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.333333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.006658865 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | 0.0857      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.18        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 18          |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.416666666666664
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 195          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0068090213 |
# |    clip_fraction        | 0.0867       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.83        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.41         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0368      |
# |    value_loss           | 13.3         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.64583333333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -369         |
# | time/                   |              |
# |    fps                  | 196          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0072140926 |
# |    clip_fraction        | 0.0959       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.83        |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.15         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 10.7         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.91666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.007272178 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.36        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 9.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.02777777777777
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -368       |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 6          |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00796932 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.81      |
# |    explained_variance   | 0.0422     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.05       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.038     |
# |    value_loss           | 7.81       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 105.98809523809524
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 7            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0074562207 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.81        |
# |    explained_variance   | 0.0269       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.31         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0357      |
# |    value_loss           | 7.28         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 107.95833333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -367       |
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 8          |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00885397 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.8       |
# |    explained_variance   | 0.0253     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.38       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0386    |
# |    value_loss           | 6.33       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.68518518518519
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 9           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009208024 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.26        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0386     |
# |    value_loss           | 4.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.80833333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 10          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009982504 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.15        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.97727272727273
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -365       |
# | time/                   |            |
# |    fps                  | 184        |
# |    iterations           | 11         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.01044842 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.77      |
# |    explained_variance   | 0.00476    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.85       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0438    |
# |    value_loss           | 3.52       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.57638888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 12          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011131922 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0102      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0828      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 3.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.6153846153846
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 13          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012484945 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 132.63690476190476
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 14          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012562129 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.0164      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.319       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.4388888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 15          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.013409227 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.0335      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.25        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.88020833333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 16          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011688993 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.73039215686273
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 17          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010622097 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.05        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.047      |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.46296296296296
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -356         |
# | time/                   |              |
# |    fps                  | 187          |
# |    iterations           | 18           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0100790635 |
# |    clip_fraction        | 0.203        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.31         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0448      |
# |    value_loss           | 2.82         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.84649122807016
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 19          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009359844 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.05        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 3.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.175
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 20          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009632513 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.557       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0426     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.21428571428572
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 21          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009344198 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.494       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.02272727272728
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 22          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009112194 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.69202898550725
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -349         |
# | time/                   |              |
# |    fps                  | 181          |
# |    iterations           | 23           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0096397195 |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.582        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0461      |
# |    value_loss           | 2.71         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.31944444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 24          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008205669 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.85        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.72666666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 25           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0084677525 |
# |    clip_fraction        | 0.178        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.04         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0456      |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.99679487179486
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 26          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008026913 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.20987654320987
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 27          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008959776 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.451       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.36309523809524
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -338         |
# | time/                   |              |
# |    fps                  | 175          |
# |    iterations           | 28           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0075592147 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.31        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.34         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0383      |
# |    value_loss           | 2.98         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.43965517241378
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 29          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008568667 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.32        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.49166666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -333        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 30          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008922344 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.17       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.5188172043011
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 31          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008121433 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.929       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.54166666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -329         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 32           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0086818915 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.03        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.799        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0484      |
# |    value_loss           | 2.75         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.50757575757575
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -326        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 33          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008199689 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.97        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.49754901960785
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 34          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009748245 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.878       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.46904761904761
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -320        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 35          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009067037 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.34490740740742
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 36          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009470233 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.975       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.2927927927928
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 37          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.009230217 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0487     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.234649122807
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -312        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 38          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008307903 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 3.18        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.19444444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -309        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 39          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.009598799 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.715       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.18958333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 40          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009113112 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.822       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0489     |
# |    value_loss           | 3.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.1768292682927
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 41          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008223224 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 176.28968253968253
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 42          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008560588 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.44379844961242
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 43          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009860925 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.903       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0496     |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.60795454545453
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -293         |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 44           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0075293016 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.14         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0457      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.72592592592594
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 45           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0073930444 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.34         |
# ...
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0316     |
# |    value_loss           | 3.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.94731800766283
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -82.5        |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 87           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0059909364 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.28         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 3.7          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 214.4905303030303
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -78.5       |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 88          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006372843 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.8         |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 3.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 214.9756554307116
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -75.4        |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 89           |
# |    time_elapsed         | 539          |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0053352118 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.33         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0286      |
# |    value_loss           | 4            |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.48611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -71.5       |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 90          |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006519531 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 3.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.98443223443223
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -68          |
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 91           |
# |    time_elapsed         | 548          |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0071145752 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.42         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0358      |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.48731884057972
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -64.6       |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 92          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005872381 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.64        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 3.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.00358422939067
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -61.7        |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 93           |
# |    time_elapsed         | 557          |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0064301593 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.45         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0331      |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.4964539007092
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -58.6        |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 94           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0064365426 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.73         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.033       |
# |    value_loss           | 3.62         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.00263157894736
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -55.6        |
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 95           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0068463534 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.66         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0325      |
# |    value_loss           | 3.64         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.47048611111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -52.7       |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 96          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006417646 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.67        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0327     |
# |    value_loss           | 3.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.92268041237114
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 97          |
# |    time_elapsed         | 573         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.005982656 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.37755102040816
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -48.1        |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 98           |
# |    time_elapsed         | 578          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0059548346 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.8          |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0359      |
# |    value_loss           | 3.38         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.82407407407408
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -46.1        |
# | time/                   |              |
# |    fps                  | 174          |
# |    iterations           | 99           |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0057088695 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.62         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0318      |
# |    value_loss           | 3.75         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.27166666666668
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -43.8        |
# | time/                   |              |
# |    fps                  | 174          |
# |    iterations           | 100          |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0056211175 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.66         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0365      |
# |    value_loss           | 3.58         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 80.3
# Overall Average Successful Assignments: 175.26720784575423
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 154.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 277.0

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")


# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks400Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -384.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.916666666666666
# All assignments history: [17, 10, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    fps             | 337      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -270.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.708333333333336
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0071853753 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | -0.0996      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 3.32         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0406      |
# |    value_loss           | 17.9         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -192.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.666666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.007183321 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | -0.00594    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.61        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.0625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007041293 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.0623      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.43        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -280.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.8
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0071035014 |
# |    clip_fraction        | 0.0969       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.82        |
# |    explained_variance   | -0.0238      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.51         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0365      |
# |    value_loss           | 10           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -234.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.20833333333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -369         |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 6            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077300714 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.81        |
# |    explained_variance   | -0.0279      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.31         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 8.34         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 82.58333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008403315 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.000601    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 6.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 91.35416666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008220302 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | -0.0123     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 5.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.62037037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009087941 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.96        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 5.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.14166666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 10          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008838493 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00166     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.587       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 4.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 108.72727272727273
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 11          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010296926 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | -0.000187   |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.57638888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011433594 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.00358     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.996       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.83974358974359
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 13          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012601015 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.00468     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.943       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.6547619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 14          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014502921 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.00319     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.828       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0495     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.06111111111112
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 15          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012517742 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.0167      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.342       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.16145833333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 16          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012032601 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.0305      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.6         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 125.02450980392157
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 17          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.009798948 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.087       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.86        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 126.79166666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -361       |
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 18         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00886194 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.7       |
# |    explained_variance   | 0.144      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.14       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0387    |
# |    value_loss           | 2.64       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.48684210526315
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 19          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.008935763 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0164      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.0
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -358       |
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 20         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00994261 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.65      |
# |    explained_variance   | 0.188      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.817      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0471    |
# |    value_loss           | 2.89       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.57142857142858
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 21          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009096321 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.358       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.17045454545453
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 22          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009189907 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.684       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.53985507246378
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -353       |
# | time/                   |            |
# |    fps                  | 278        |
# |    iterations           | 23         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.00966586 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.57      |
# |    explained_variance   | 0.254      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.25       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0475    |
# |    value_loss           | 2.81       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.15625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 24          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008240359 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.608       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 3.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.73
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 25          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.009508166 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.1         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.16346153846155
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 26          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008624364 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.62654320987653
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 27          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008229433 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.352       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.03571428571428
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 28          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007859462 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.13        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.3448275862069
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 29          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.010005968 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.269       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.73611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 30          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009676775 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.34677419354838
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 31          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008854199 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0471     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.04166666666666
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -333       |
# | time/                   |            |
# |    fps                  | 272        |
# |    iterations           | 32         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00828062 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.06      |
# |    explained_variance   | 0.228      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.38       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0446    |
# |    value_loss           | 3.22       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.62373737373738
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -331        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 33          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008674512 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.22        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.047      |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.32843137254903
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -328       |
# | time/                   |            |
# |    fps                  | 270        |
# |    iterations           | 34         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00800571 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.93      |
# |    explained_variance   | 0.159      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.63       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0453    |
# |    value_loss           | 3.39       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.98333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 35          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.007550506 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.931       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.52083333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 36          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007729215 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.943       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 3.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.07657657657657
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 37          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.008009473 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.877       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.62719298245614
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -314       |
# | time/                   |            |
# |    fps                  | 266        |
# |    iterations           | 38         |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00866224 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.61      |
# |    explained_variance   | 0.311      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.808      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0472    |
# |    value_loss           | 3.01       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.1260683760684
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -310        |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 39          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008100676 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.49        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 3.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.51875
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -307         |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 40           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0071069337 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.42        |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.17         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0439      |
# |    value_loss           | 3.6          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.8617886178862
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -304        |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 41          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008500927 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.979       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.2281746031746
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 42          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008522388 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.58527131782947
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 43          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.006654585 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.9034090909091
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -293        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 44          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007307475 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.0851851851852
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 45          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008055938 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# ...
# | train/                  |             |
# |    approx_kl            | 0.006922761 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.49        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 3.4         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 201.21743295019158
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -90.3       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 87          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.008891378 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 3.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 201.7973484848485
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -87.8        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 88           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0069347396 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.951        |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0358      |
# |    value_loss           | 2.71         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 202.37640449438203
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -85.7      |
# | time/                   |            |
# |    fps                  | 229        |
# |    iterations           | 89         |
# |    time_elapsed         | 397        |
# |    total_timesteps      | 91136      |
# | train/                  |            |
# |    approx_kl            | 0.00824222 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.484      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.18       |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0385    |
# |    value_loss           | 3.28       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 202.925
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -83         |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 90          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005815825 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.15        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 3.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 142.0
# Standard deviation of reward: 0.0
# Average successful assignments: 203.51007326007326
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -80.3       |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 91          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.006163749 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.34        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 204.0570652173913
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -77.8       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 92          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006767368 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 3.18        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 204.58064516129033
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -75.9       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 93          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006105985 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.58        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 205.10195035460993
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 94          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006210056 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.63        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 3.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 205.61754385964912
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -71.8        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 95           |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0069550136 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.521        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.64         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0378      |
# |    value_loss           | 3.53         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 206.12586805555554
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 96          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006418133 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.82        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 3.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 206.64862542955328
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -67.4        |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 97           |
# |    time_elapsed         | 432          |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0060254233 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.75         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0393      |
# |    value_loss           | 3.84         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.13945578231292
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -65.5        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 98           |
# |    time_elapsed         | 436          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0064613046 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.64         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0371      |
# |    value_loss           | 3.43         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.63131313131314
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -63.8        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 99           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0069666523 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.69         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0348      |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 208.10083333333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -62.4        |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 100          |
# |    time_elapsed         | 443          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063201096 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.595        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.48         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.037       |
# |    value_loss           | 3.32         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 52.98
# Overall Average Successful Assignments: 161.31549546140198
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 144.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 272.0

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")


# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks400Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.083333333333332
# All assignments history: [21, 10, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -369     |
# | time/              |          |
# |    fps             | 303      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -330.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.958333333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0074489396 |
# |    clip_fraction        | 0.0751       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | -0.137       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.07         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0382      |
# |    value_loss           | 16.2         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.583333333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0072928937 |
# |    clip_fraction        | 0.0868       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.83        |
# |    explained_variance   | -0.0549      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.22         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0368      |
# |    value_loss           | 12.2         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -362.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.270833333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065695136 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.82        |
# |    explained_variance   | 0.0442       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.71         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0342      |
# |    value_loss           | 11.2         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -380.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.033333333333335
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0077569233 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.82        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.39         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0358      |
# |    value_loss           | 9.28         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -330.0
# Standard deviation of reward: 0.0
# Average successful assignments: 26.13888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008346751 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | -0.0265     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.93        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 7.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -298.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.821428571428573
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008140056 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.00669     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.26        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.038      |
# |    value_loss           | 6.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -190.0
# Standard deviation of reward: 0.0
# Average successful assignments: 36.6875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008024637 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | -0.00831    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 5.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -190.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.611111111111114
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009895408 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | -0.00199    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.29        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 4.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -272.0
# Standard deviation of reward: 0.0
# Average successful assignments: 43.983333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 10          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008893935 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.000602    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.608       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 4.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 53.24242424242424
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010304587 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00136     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.884       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.043      |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.0625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010957932 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00453     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0337      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 3.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.32692307692308
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 13          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012299823 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.00542     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0922     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.9047619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 14          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012088817 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | -0.00109    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.77        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0426     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.60555555555555
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 15          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.013587486 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.00122     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.29        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.99479166666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 16          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014734687 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.00245     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.12        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.051      |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.50490196078431
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -361         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 17           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0136813875 |
# |    clip_fraction        | 0.294        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.00953      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.58         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0528      |
# |    value_loss           | 2.94         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.4675925925926
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 18           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0111927865 |
# |    clip_fraction        | 0.237        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.138        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0503      |
# |    value_loss           | 2.99         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.06140350877193
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 19          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.008642538 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 94.54583333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 20          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007568282 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.138       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.90873015873017
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 21          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.007808461 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.196       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 102.91287878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 22          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008408623 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.775       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 106.56884057971014
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -353         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 23           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0067031933 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.371        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0373      |
# |    value_loss           | 3.12         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.85763888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 24          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006767909 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.8         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0374     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.88333333333334
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -350       |
# | time/                   |            |
# |    fps                  | 276        |
# |    iterations           | 25         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.00670687 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.52      |
# |    explained_variance   | 0.329      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.305      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0382    |
# |    value_loss           | 2.82       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.74038461538461
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 26          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007961285 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.326       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.38888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 27          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007607669 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.8         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.11607142857143
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 28           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0075758686 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.353        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.05         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0406      |
# |    value_loss           | 3.09         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.71264367816092
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -343         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 29           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0072561884 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.33        |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.83         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0412      |
# |    value_loss           | 3            |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 126.14444444444445
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 30          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008462326 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.694       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.53225806451613
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 31          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.007708675 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.69010416666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 32          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008766202 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.96        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 132.83838383838383
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -333         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 33           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0067967093 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.11        |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.873        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0402      |
# |    value_loss           | 3.08         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.85294117647058
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 34          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007686979 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.868       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.8738095238095
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -327       |
# | time/                   |            |
# |    fps                  | 276        |
# |    iterations           | 35         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.00733595 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.96      |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.764      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0408    |
# |    value_loss           | 2.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.77546296296296
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 36          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007048445 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.58783783783784
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 37          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.008442691 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.49        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.41666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -319        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 38          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007954409 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.614       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.18376068376068
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 39          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.007520184 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.94        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.96875
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -313         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 40           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0072214794 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.985        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0454      |
# |    value_loss           | 3.3          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.6747967479675
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -310        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 41          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.007906741 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.48        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.4047619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 42          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006306173 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.903       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.02713178294573
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -303         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 43           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0069830194 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.36        |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.876        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0402      |
# |    value_loss           | 2.89         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.61363636363637
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 44          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009134531 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.826       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0442     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.17222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 45          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008301077 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.511       |
# ...
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.46         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 3.56         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 192.45689655172413
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -90.1       |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 87          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.006226564 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.53        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 3.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 193.04924242424244
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -86.4       |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 88          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006286498 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0306     |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 193.60767790262173
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -83.1        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 89           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0061245207 |
# |    clip_fraction        | 0.0973       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.53         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0305      |
# |    value_loss           | 3.24         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 194.1648148148148
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -80.3        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 90           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0072977347 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.3          |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0376      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 194.71611721611723
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -77.5        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 91           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0068944935 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.516        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.27         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0361      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 195.27626811594203
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -74.5        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 92           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0066409917 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.25         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0361      |
# |    value_loss           | 3.33         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 195.81989247311827
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -71.7        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 93           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0060771857 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.18         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0344      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 196.3386524822695
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -69.4       |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 94          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006779716 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 196.8640350877193
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -67.2        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 95           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0066011827 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.84         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0371      |
# |    value_loss           | 3.44         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 197.36892361111111
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -65.2        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 96           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0059914505 |
# |    clip_fraction        | 0.0987       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.47         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0302      |
# |    value_loss           | 3.63         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 197.86254295532646
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -63.4        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 97           |
# |    time_elapsed         | 356          |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0056548817 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.57         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0329      |
# |    value_loss           | 3.68         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 198.36309523809524
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -61.3        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 98           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0067391316 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.12         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0379      |
# |    value_loss           | 3.18         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 198.85690235690237
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -58.9        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 99           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0064947456 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.24         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0366      |
# |    value_loss           | 3.28         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 199.35
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -57.3       |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 100         |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006392861 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.41        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 32.14
# Overall Average Successful Assignments: 143.3307365982622
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 122.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 261.0
