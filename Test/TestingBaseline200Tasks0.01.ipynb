# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.01.csv')
tasks_df = pd.read_csv('RandomTasks200.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")

# Load new task dataset for testing
new_tasks_df = pd.read_csv('RandomTasks200Test.csv')
new_tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)
test_env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, new_tasks_df), n_envs=1)

# Evaluate the model on the new test environment
mean_reward, std_reward = evaluate_policy(model, test_env, n_eval_episodes=10)
# Extract the successful assignments history from the test environment
successful_assignments = test_env.envs[0].env.get_average_success()

print("---- Testing Summary ----")
print(f"Mean Reward: {mean_reward}")
print(f"Standard Deviation of Reward: {std_reward}")
print(f"Average Successful Assignments in Testing: {successful_assignments}")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.066666666666666
# All assignments history: [10, 9, 12, 5, 10, 27, 27, 27, 27, 27, 27, 27, 27, 27, 27]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -182     |
# | time/              |          |
# |    fps             | 576      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -128.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.766666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.010016383 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.245      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.64        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0561     |
# |    value_loss           | 16.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -182.0
# Standard deviation of reward: 0.0
# Average successful assignments: 18.57777777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.012348394 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.157      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.93        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.85
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012958124 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0242     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.15        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.059      |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 18.133333333333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -184         |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0143447975 |
# |    clip_fraction        | 0.266        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | 0.00411      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.09         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0601      |
# |    value_loss           | 8.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 18.033333333333335
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -184       |
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 6          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01614993 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | 0.0629     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.13       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0632    |
# |    value_loss           | 8.26       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.36190476190476
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016373498 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0622      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.82        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 7.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.908333333333335
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017740823 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0692      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.54        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 6.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.22222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018895656 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0798      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0633     |
# |    value_loss           | 5.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.966666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019734038 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.095       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.19        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0642     |
# |    value_loss           | 5.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.933333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020310871 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 5.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -144.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.372222222222224
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021100508 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0627     |
# |    value_loss           | 4.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.61025641025641
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.023311328 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -172.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.271428571428572
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024962148 |
# |    clip_fraction        | 0.553       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.96        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0651     |
# |    value_loss           | 4.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.844444444444445
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.025302589 |
# |    clip_fraction        | 0.544       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.153       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0661     |
# |    value_loss           | 4.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -182.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.345833333333335
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025227152 |
# |    clip_fraction        | 0.558       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.743       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0681     |
# |    value_loss           | 4.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.27843137254902
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.025790598 |
# |    clip_fraction        | 0.543       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.89        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0666     |
# |    value_loss           | 4.13        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -144.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.492592592592594
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022990767 |
# |    clip_fraction        | 0.493       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.32        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0649     |
# |    value_loss           | 4.3         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 18.11578947368421
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.022740308 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.48        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0659     |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 19.416666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024434004 |
# |    clip_fraction        | 0.519       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.15        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0669     |
# |    value_loss           | 4.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.476190476190474
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 21          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.023384515 |
# |    clip_fraction        | 0.509       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.903       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0682     |
# |    value_loss           | 4.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.52121212121212
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 22          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023632573 |
# |    clip_fraction        | 0.484       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.51        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.068      |
# |    value_loss           | 4.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.6231884057971
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 23          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.025192395 |
# |    clip_fraction        | 0.54        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.073      |
# |    value_loss           | 4.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.005555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 24          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022292327 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0675     |
# |    value_loss           | 3.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.981333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 25          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.019439287 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.967       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0643     |
# |    value_loss           | 4.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.956410256410255
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 26          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021182954 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.05        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 4.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 26.77283950617284
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 27          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.022603778 |
# |    clip_fraction        | 0.477       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.925       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0688     |
# |    value_loss           | 4.13        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.507142857142856
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 28          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020914383 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.571       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0664     |
# |    value_loss           | 4.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.27126436781609
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 29          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.020638686 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.27        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 3.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.92222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 30          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021289496 |
# |    clip_fraction        | 0.446       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.67        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0686     |
# |    value_loss           | 4.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.49462365591398
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -183      |
# | time/                   |           |
# |    fps                  | 322       |
# |    iterations           | 31        |
# |    time_elapsed         | 98        |
# |    total_timesteps      | 31744     |
# | train/                  |           |
# |    approx_kl            | 0.0237915 |
# |    clip_fraction        | 0.494     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.26     |
# |    explained_variance   | 0.645     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.55      |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.0712   |
# |    value_loss           | 3.98      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.916666666666668
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -183       |
# | time/                   |            |
# |    fps                  | 316        |
# |    iterations           | 32         |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02168328 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.963      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0681    |
# |    value_loss           | 3.87       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.34949494949495
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -183       |
# | time/                   |            |
# |    fps                  | 312        |
# |    iterations           | 33         |
# |    time_elapsed         | 108        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.02267455 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.646      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.604      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0698    |
# |    value_loss           | 4.07       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.894117647058824
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 34          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022177773 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.61        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0688     |
# |    value_loss           | 3.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.415238095238095
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 35          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.022507055 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.65        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.07       |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.80185185185185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 36          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.023451213 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0698     |
# |    value_loss           | 3.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.016216216216215
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 37          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.023541026 |
# |    clip_fraction        | 0.485       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.53        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0717     |
# |    value_loss           | 3.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.34035087719298
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 38          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023245975 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.905       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0703     |
# |    value_loss           | 3.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.83418803418803
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 39          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.024668586 |
# |    clip_fraction        | 0.501       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.89        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.072      |
# |    value_loss           | 3.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.525
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 40          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022988778 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.6         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0701     |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.167479674796745
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -182       |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 41         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.02196994 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.583      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0668    |
# |    value_loss           | 3.56       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.060317460317464
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 42          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022388177 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.27        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0705     |
# |    value_loss           | 3.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.7937984496124
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 43          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.022795243 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.916       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0696     |
# |    value_loss           | 3.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 36.5030303030303
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -182        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 44          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021243263 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.789       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0675     |
# |    value_loss           | 3.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 37.04888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -181        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 45          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.021861874 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.51        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0714     |
# |    value_loss           | 3.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# ...
# |    fps                  | 245         |
# |    iterations           | 86          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.018204777 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.279       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0667     |
# |    value_loss           | 2.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.54942528735632
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 87          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.019434977 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.549       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0694     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.987878787878785
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 88          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019659277 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.865       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0698     |
# |    value_loss           | 2.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 56.38801498127341
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 89          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.018301968 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0242      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0688     |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 56.806666666666665
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 90          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018475443 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.586       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0697     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.184615384615384
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 91          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.019580845 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.18        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0728     |
# |    value_loss           | 2.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.57536231884058
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 92          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019087713 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.331       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0717     |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.94336917562724
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 93          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.020175997 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.127       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0703     |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.351063829787236
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 94          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.019165687 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.685       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0699     |
# |    value_loss           | 2           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.72982456140351
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 95          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.019046783 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.215       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0711     |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.09166666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 96          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019582463 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.19       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.827       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0713     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.442611683848796
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -176       |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 97         |
# |    time_elapsed         | 419        |
# |    total_timesteps      | 99328      |
# | train/                  |            |
# |    approx_kl            | 0.01882268 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.19      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.00956    |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0711    |
# |    value_loss           | 1.96       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.779591836734696
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -176       |
# | time/                   |            |
# |    fps                  | 235        |
# |    iterations           | 98         |
# |    time_elapsed         | 425        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01896314 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.19      |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.367      |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.0703    |
# |    value_loss           | 1.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.121885521885524
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 99          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.017880902 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.18       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0716     |
# |    value_loss           | 2.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.47
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 100         |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.018856548 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.18       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.207       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0709     |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -28.5
# Overall Average Successful Assignments: 37.949184124864296
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---- Testing Summary ----
# Mean Reward: 50.0
# Standard Deviation of Reward: 0.0
# Average Successful Assignments in Testing: 125.0
