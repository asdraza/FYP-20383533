# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -376.0
# Standard deviation of reward: 0.0
# Average successful assignments: 12.583333333333334
# All assignments history: [11, 20, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -369     |
# | time/              |          |
# |    fps             | 144      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -342.0
# Standard deviation of reward: 0.0
# Average successful assignments: 19.25
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -374         |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0081374915 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | 0.0444       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.82         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0501      |
# |    value_loss           | 17.8         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -350.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.72222222222222
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 135        |
# |    iterations           | 3          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.01182378 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | 1.03e-05   |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.82       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0592    |
# |    value_loss           | 13.6       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -316.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.833333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013811392 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.056      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0665     |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -312.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.5
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 5          |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.01371921 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | 0.00395    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.37       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0576    |
# |    value_loss           | 9.82       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -332.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.11111111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 6           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014382845 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.00366    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.15        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 8.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -346.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.654761904761905
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 7           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016295496 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0178      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0628     |
# |    value_loss           | 6.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -316.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.864583333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 8           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016613774 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.000437   |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0612     |
# |    value_loss           | 6.13        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -346.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.416666666666668
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 9          |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.01727343 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.28      |
# |    explained_variance   | 0.0102     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.89       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0583    |
# |    value_loss           | 5.37       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -314.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.358333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 10          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019628674 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.000585    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.62        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0647     |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -128.0
# Standard deviation of reward: 0.0
# Average successful assignments: 37.18939393939394
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 11          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.019229356 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00815     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.376       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0595     |
# |    value_loss           | 3.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.61805555555556
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 108        |
# |    iterations           | 12         |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02135685 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00576    |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.0768    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0656    |
# |    value_loss           | 3.46       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.11538461538461
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 13          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.021277329 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0079      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.382       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0596     |
# |    value_loss           | 3.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.89285714285714
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 14          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022728574 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00813     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.426       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.2
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 104        |
# |    iterations           | 15         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.02654941 |
# |    clip_fraction        | 0.606      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0075     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.33       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0667    |
# |    value_loss           | 3.14       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -316.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.0625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 16          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.027091242 |
# |    clip_fraction        | 0.593       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0239      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.244       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0657     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -320.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.1029411764706
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 17          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.024116857 |
# |    clip_fraction        | 0.531       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0797      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.83        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.058      |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.63425925925925
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 18          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023894338 |
# |    clip_fraction        | 0.524       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.243       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0626     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.2719298245614
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 19          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.021664912 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.29        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0624     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.15
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 20          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023206716 |
# |    clip_fraction        | 0.509       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.233       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0657     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.39285714285714
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 21          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.019405283 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.7         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0575     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.39015151515152
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 22          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021164462 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0976     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0615     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.07246376811594
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 23          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.023589408 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0456     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0659     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -244.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.57291666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 24          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022339866 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.872       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -314.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.97
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 25          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.022617284 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.157       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0643     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -310.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.56089743589743
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 26          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021043818 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.26        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -240.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.31172839506173
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 27         |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 27648      |
# | train/                  |            |
# |    approx_kl            | 0.02183568 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.302      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.24       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.062     |
# |    value_loss           | 2.8        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.18452380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 28          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019961406 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.915       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -210.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.40229885057471
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 29          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.020373177 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0635     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.42222222222222
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 30         |
# |    time_elapsed         | 318        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01883181 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.322      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.896      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0624    |
# |    value_loss           | 2.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.77688172043011
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 31          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.018660607 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.112       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.59895833333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 32         |
# |    time_elapsed         | 341        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01818796 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.365      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.584      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.057     |
# |    value_loss           | 2.57       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 82.59343434343434
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -372      |
# | time/                   |           |
# |    fps                  | 95        |
# |    iterations           | 33        |
# |    time_elapsed         | 353       |
# |    total_timesteps      | 33792     |
# | train/                  |           |
# |    approx_kl            | 0.0173208 |
# |    clip_fraction        | 0.319     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.26     |
# |    explained_variance   | 0.382     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.595     |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.058    |
# |    value_loss           | 2.63      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.17892156862744
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 34          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018334553 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.852       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0599     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.60952380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 35          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.021020593 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.076       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0624     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.90046296296296
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 36          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017712172 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.579       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0601     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.32432432432432
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 37          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017227765 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.36        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.20614035087719
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 38          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017037421 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.7         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0595     |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 92.13034188034187
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 39          |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.017982462 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.846       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0596     |
# |    value_loss           | 2.47        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.9875
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 40         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01599131 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.0213    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0591    |
# |    value_loss           | 2.56       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 95.67073170731707
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 93           |
# |    iterations           | 41           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0149818305 |
# |    clip_fraction        | 0.28         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.24        |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.19         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0576      |
# |    value_loss           | 2.94         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 96.85317460317461
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 42          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016907314 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 97.71899224806202
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 43          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.015904488 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.22       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.39015151515152
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 44          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017907627 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0777     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0582     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.19074074074074
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 45          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.015771016 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.423       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.06       |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.90579710144928
# All assignments history: []
# -----------------------------------------
# ...
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.0707    |
# |    value_loss           | 2.26       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.93701550387595
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 86          |
# |    time_elapsed         | 1006        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.019409604 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.073      |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.60919540229884
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 87          |
# |    time_elapsed         | 1019        |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.020531382 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.95       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.659       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0758     |
# |    value_loss           | 2.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.29545454545453
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 88          |
# |    time_elapsed         | 1030        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018693479 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.213       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0711     |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.9316479400749
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 89          |
# |    time_elapsed         | 1044        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.017349226 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.91       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0798      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0746     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.5574074074074
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 90          |
# |    time_elapsed         | 1058        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019281505 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.15        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0776     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.18223443223442
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 91          |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.018169586 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.188       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0735     |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.8125
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 92          |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019230515 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.84       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.634       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.076      |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.39874551971326
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 93          |
# |    time_elapsed         | 1098        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.018791307 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.144       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0757     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.99379432624113
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 94          |
# |    time_elapsed         | 1115        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.019287115 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.961       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0769     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.55263157894737
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -346       |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 95         |
# |    time_elapsed         | 1130       |
# |    total_timesteps      | 97280      |
# | train/                  |            |
# |    approx_kl            | 0.01968184 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.74      |
# |    explained_variance   | 0.426      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.422      |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0757    |
# |    value_loss           | 2.49       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.10329861111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 96          |
# |    time_elapsed         | 1145        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015772847 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.862       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.66323024054984
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 97          |
# |    time_elapsed         | 1160        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.018538876 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.227       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0752     |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.21428571428572
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 98          |
# |    time_elapsed         | 1174        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018233355 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.63       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.837       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0747     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.75
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 99          |
# |    time_elapsed         | 1190        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.017472725 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.61       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.848       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0744     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.26
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -339      |
# | time/                   |           |
# |    fps                  | 85        |
# |    iterations           | 100       |
# |    time_elapsed         | 1203      |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.0194894 |
# |    clip_fraction        | 0.416     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -7.57     |
# |    explained_variance   | 0.384     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.433     |
# |    n_updates            | 990       |
# |    policy_gradient_loss | -0.0774   |
# |    value_loss           | 2.61      |
# ---------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -67.7
# Overall Average Successful Assignments: 97.48301746182338

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -378.0
# Standard deviation of reward: 0.0
# Average successful assignments: 11.416666666666666
# All assignments history: [14, 13, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    fps             | 91       |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -310.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.291666666666668
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -376         |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 2            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0080583915 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | -0.00989     |
# |    learning_rate        | 0.00018      |
# |    loss                 | 3.08         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0499      |
# |    value_loss           | 19           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.805555555555557
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -376         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 3            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0115102595 |
# |    clip_fraction        | 0.168        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | -0.0492      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.97         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0597      |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -354.0
# Standard deviation of reward: 0.0
# Average successful assignments: 26.354166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013333991 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0512     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.66        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0625     |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -372.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.716666666666665
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 5           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.013989274 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0453      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 8.47        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -366.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.48611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 6           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012430085 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0447     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.88        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 8.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -236.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.428571428571427
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 7           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.015777972 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.00348     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0589     |
# |    value_loss           | 6.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -396.0
# Standard deviation of reward: 0.0
# Average successful assignments: 26.145833333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 8           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017236564 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0114     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.927       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0632     |
# |    value_loss           | 5.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -348.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.953703703703702
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 9           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.017438514 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0175      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0574     |
# |    value_loss           | 5.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -236.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.491666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 10          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020091677 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00101     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.113       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0633     |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 37.43181818181818
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 11          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020733345 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0837      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0642     |
# |    value_loss           | 3.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -182.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.076388888888886
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 12          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021679468 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00442     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.604       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 48.60897435897436
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 13          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.023638835 |
# |    clip_fraction        | 0.527       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0093      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.177      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.75
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 14          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024201095 |
# |    clip_fraction        | 0.553       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.381      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -224.0
# Standard deviation of reward: 0.0
# Average successful assignments: 56.16111111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 15          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.026236031 |
# |    clip_fraction        | 0.578       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.56        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0635     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.208333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 16          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.029677374 |
# |    clip_fraction        | 0.626       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.035       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.424      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0655     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -204.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.63235294117647
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 17         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.02661631 |
# |    clip_fraction        | 0.585      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.128      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2          |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0662    |
# |    value_loss           | 2.69       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -226.0
# Standard deviation of reward: 0.0
# Average successful assignments: 62.379629629629626
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 18          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.027486108 |
# |    clip_fraction        | 0.569       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0668     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -184.0
# Standard deviation of reward: 0.0
# Average successful assignments: 63.98684210526316
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 19          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.025720239 |
# |    clip_fraction        | 0.546       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0891      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0647     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -342.0
# Standard deviation of reward: 0.0
# Average successful assignments: 62.12083333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 20          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026129793 |
# |    clip_fraction        | 0.539       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.21        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0659     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -320.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.861111111111114
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 21         |
# |    time_elapsed         | 295        |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.02661737 |
# |    clip_fraction        | 0.537      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.308      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.06       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0671    |
# |    value_loss           | 2.61       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -252.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.984848484848484
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 22          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022225656 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.664       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0646     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 62.27173913043478
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 23          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.022631217 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.68        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -122.0
# Standard deviation of reward: 0.0
# Average successful assignments: 64.60416666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 24          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.020823672 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0554      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.23333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 25          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.022540856 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.00103     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.68910256410257
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 26          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023153052 |
# |    clip_fraction        | 0.468       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.177       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0673     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.16666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 27          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.024046205 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.02        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.14285714285714
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 28          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022337561 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0656     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.42528735632185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 29          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.021397408 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.104      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0628     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.73333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 30          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020706369 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.843       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0622     |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.18010752688173
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 31          |
# |    time_elapsed         | 440         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.020954672 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0633     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.5390625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 32          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019430652 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0631     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -130.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.74242424242425
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 33         |
# |    time_elapsed         | 468        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.02041157 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.178      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0632    |
# |    value_loss           | 2.61       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -130.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.87990196078431
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 34          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.019322634 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.293      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.063      |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.4
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 35          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.020744376 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.85        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0628     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.05555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 36          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017013881 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.606       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0575     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.44594594594595
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 37          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.018468224 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.198      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.71710526315789
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 38          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016452394 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.884       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0559     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -104.0
# Standard deviation of reward: 0.0
# Average successful assignments: 82.84615384615384
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 39          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.018857298 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0372     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0589     |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.00208333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 40         |
# |    time_elapsed         | 568        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01977089 |
# |    clip_fraction        | 0.394      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.448      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.239     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0626    |
# |    value_loss           | 2.44       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.21747967479675
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 41          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.017498937 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.803       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0614     |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.0734126984127
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 42         |
# |    time_elapsed         | 596        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01829672 |
# |    clip_fraction        | 0.331      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.451      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.571      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0619    |
# |    value_loss           | 2.57       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.53682170542636
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 43          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.015020486 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.351       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0566     |
# |    value_loss           | 2.47        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.82575757575758
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 44          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018005531 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.945       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0646     |
# |    value_loss           | 2.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.17592592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 45          |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.016383134 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.807       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0591     |
# |    value_loss           | 2.42        |
# -----------------------------------------
# ...
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.429       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0715     |
# |    value_loss           | 1.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.49903100775194
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -363       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 86         |
# |    time_elapsed         | 1250       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02016496 |
# |    clip_fraction        | 0.426      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.13      |
# |    explained_variance   | 0.654      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0356     |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0764    |
# |    value_loss           | 1.85       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.30459770114942
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -363       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 87         |
# |    time_elapsed         | 1266       |
# |    total_timesteps      | 89088      |
# | train/                  |            |
# |    approx_kl            | 0.01956324 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.13      |
# |    explained_variance   | 0.651      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.239      |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0727    |
# |    value_loss           | 1.94       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.07007575757575
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 88          |
# |    time_elapsed         | 1282        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.017140983 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.127       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0701     |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.87640449438203
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 89          |
# |    time_elapsed         | 1297        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.017265227 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.144      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0665     |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.68611111111112
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 90          |
# |    time_elapsed         | 1312        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018567266 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.11       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.803       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0746     |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.49633699633699
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 91          |
# |    time_elapsed         | 1327        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.017151127 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.11       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.134       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0684     |
# |    value_loss           | 1.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.29800724637681
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -361       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 92         |
# |    time_elapsed         | 1342       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01886553 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.1       |
# |    explained_variance   | 0.686      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.406      |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0729    |
# |    value_loss           | 1.81       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.10215053763442
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -360       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 93         |
# |    time_elapsed         | 1357       |
# |    total_timesteps      | 95232      |
# | train/                  |            |
# |    approx_kl            | 0.01911834 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.1       |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.133     |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0768    |
# |    value_loss           | 2.13       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.87234042553192
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -360       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 94         |
# |    time_elapsed         | 1372       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01715178 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.08      |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0969     |
# |    n_updates            | 930        |
# |    policy_gradient_loss | -0.0731    |
# |    value_loss           | 2.07       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 117.6280701754386
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 95          |
# |    time_elapsed         | 1387        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.017318064 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.07       |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.611       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.38107638888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 96          |
# |    time_elapsed         | 1402        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018091949 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.06       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.305       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0713     |
# |    value_loss           | 2.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.10223367697594
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -359       |
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 97         |
# |    time_elapsed         | 1417       |
# |    total_timesteps      | 99328      |
# | train/                  |            |
# |    approx_kl            | 0.01948852 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.05      |
# |    explained_variance   | 0.604      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.705      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0759    |
# |    value_loss           | 2.07       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.82227891156462
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -358      |
# | time/                   |           |
# |    fps                  | 69        |
# |    iterations           | 98        |
# |    time_elapsed         | 1433      |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0190287 |
# |    clip_fraction        | 0.389     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.04     |
# |    explained_variance   | 0.655     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.271     |
# |    n_updates            | 970       |
# |    policy_gradient_loss | -0.0722   |
# |    value_loss           | 1.79      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 120.52020202020202
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 99          |
# |    time_elapsed         | 1448        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.017662488 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.695       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.072      |
# |    value_loss           | 1.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.23
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -357       |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 100        |
# |    time_elapsed         | 1463       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01704315 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.02      |
# |    explained_variance   | 0.588      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.0614    |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0739    |
# |    value_loss           | 2.21       |
# ----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -116.24
# Overall Average Successful Assignments: 83.71614747029078

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -388.0
# Standard deviation of reward: 0.0
# Average successful assignments: 6.583333333333333
# All assignments history: [14, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -381     |
# | time/              |          |
# |    fps             | 112      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -342.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.541666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -376        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008579325 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.153      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.53        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.166666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 3           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.012155972 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.112      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -360.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.479166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 4           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013128005 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0778     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0613     |
# |    value_loss           | 9.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -308.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.25
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 5           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.014924317 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.65        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0631     |
# |    value_loss           | 8.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -300.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.291666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 6           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014715549 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0442      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 7.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -242.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.035714285714285
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 7           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.015852245 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00627     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.53        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0574     |
# |    value_loss           | 6.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -190.0
# Standard deviation of reward: 0.0
# Average successful assignments: 41.010416666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 8           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018246058 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00499     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.984       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0648     |
# |    value_loss           | 5.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -238.0
# Standard deviation of reward: 0.0
# Average successful assignments: 44.175925925925924
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 9           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018637385 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0101      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.83        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0614     |
# |    value_loss           | 4.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -340.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.45
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 10          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019020692 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00952     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.923       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0601     |
# |    value_loss           | 4.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -264.0
# Standard deviation of reward: 0.0
# Average successful assignments: 43.96969696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 11          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020518053 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00892     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 3.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -230.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.458333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 12          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.022036543 |
# |    clip_fraction        | 0.48        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.15       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.09615384615385
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 13          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.023852237 |
# |    clip_fraction        | 0.528       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.881       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0641     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 52.45238095238095
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 14          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.025554743 |
# |    clip_fraction        | 0.583       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0251      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.143      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0653     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.65555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 15          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.026110774 |
# |    clip_fraction        | 0.598       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0696      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.23       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.065      |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.114583333333336
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 16         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02439119 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.794      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0608    |
# |    value_loss           | 2.67       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -264.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.254901960784316
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 17          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.024161741 |
# |    clip_fraction        | 0.501       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.316      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -294.0
# Standard deviation of reward: 0.0
# Average successful assignments: 56.68981481481482
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 18          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023982663 |
# |    clip_fraction        | 0.535       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.838       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0667     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -218.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.82017543859649
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 19          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.026110027 |
# |    clip_fraction        | 0.531       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0471      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0657     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.916666666666664
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 20         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02192449 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0593     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0617    |
# |    value_loss           | 2.64       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -232.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.53968253968254
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 21          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.023313867 |
# |    clip_fraction        | 0.494       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.791       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0624     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -248.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.79924242424242
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 22          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022470819 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.361       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.32608695652174
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 23          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.022928467 |
# |    clip_fraction        | 0.443       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.168       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0568     |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -228.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.854166666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 24          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022047538 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.24        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.061      |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 63.35333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 25          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.021247908 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.934       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.26282051282051
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 26          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020081837 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.284       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0622     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.05246913580247
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 27          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.019379575 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.367      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0583     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.52083333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 28          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019480819 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.48        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0613     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -198.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.11206896551724
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 29         |
# |    time_elapsed         | 325        |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.02083036 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.349      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.062     |
# |    value_loss           | 2.68       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -206.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.57222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 30          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018337261 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.645       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0573     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.89784946236558
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 31          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.021481927 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.737       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -184.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.59635416666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 32          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017706864 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.731       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0571     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -198.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.04797979797979
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 33          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.018560883 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.196       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0589     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -200.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.45833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 34          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016493931 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.15        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0592     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.22380952380952
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 35          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.018094916 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.393       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -144.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.23842592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 36          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016826345 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.245      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0582     |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -108.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.58108108108108
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 37          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017794523 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 2.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.67763157894737
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 38          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.018035408 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1           |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0568     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.07478632478633
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 39          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.016006207 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.301       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0561     |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.89166666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 40         |
# |    time_elapsed         | 449        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01735638 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.457      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0039     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0593    |
# |    value_loss           | 2.41       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.33739837398375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 41          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.017490104 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.156       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0586     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 82.94642857142857
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 42          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017781874 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.726       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.35077519379846
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 43          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.014547437 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.23       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.58        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.70075757575758
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 44          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017359309 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.23       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0582     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.2611111111111
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -370       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 45         |
# |    time_elapsed         | 506        |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.01878523 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.23      |
# |    explained_variance   | 0.454      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.0166    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0601    |
# |    value_loss           | 2.49       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# ...
# |    policy_gradient_loss | -0.0751     |
# |    value_loss           | 2.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 132.734496124031
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 86          |
# |    time_elapsed         | 973         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.021134317 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.708       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0744     |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.42911877394636
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 87          |
# |    time_elapsed         | 985         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.018722538 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.86       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.72        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.076      |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.0625
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -350       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 88         |
# |    time_elapsed         | 996        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01941319 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.83      |
# |    explained_variance   | 0.602      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.193      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0757    |
# |    value_loss           | 2.2        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.70411985018725
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 89          |
# |    time_elapsed         | 1007        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.019630544 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.79       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.848       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0785     |
# |    value_loss           | 2.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.3074074074074
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 90          |
# |    time_elapsed         | 1019        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018202337 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.483       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0747     |
# |    value_loss           | 2.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.9313186813187
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 91          |
# |    time_elapsed         | 1030        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.019715782 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0157     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0758     |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.5606884057971
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -345       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 92         |
# |    time_elapsed         | 1041       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01792169 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.76      |
# |    explained_variance   | 0.569      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.218      |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0743    |
# |    value_loss           | 2.71       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.15143369175627
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 93          |
# |    time_elapsed         | 1052        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.018340796 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.75       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.15        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0748     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.74290780141843
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 94          |
# |    time_elapsed         | 1062        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020594526 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.72       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0706      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0768     |
# |    value_loss           | 2.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.33684210526314
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 95          |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.020722773 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0775     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.90538194444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 96          |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020736504 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.107       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0762     |
# |    value_loss           | 2.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.4742268041237
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 97          |
# |    time_elapsed         | 1095        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.019095825 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.542       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.081      |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.05527210884352
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 98          |
# |    time_elapsed         | 1106        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017377991 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.704       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0763     |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.58585858585857
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 99          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.018094134 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.57       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.656       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0754     |
# |    value_loss           | 3.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.12083333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -334        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 100         |
# |    time_elapsed         | 1127        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.018581288 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.859       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0752     |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -70.96
# Overall Average Successful Assignments: 92.24495333170653

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -380.0
# Standard deviation of reward: 0.0
# Average successful assignments: 10.75
# All assignments history: [15, 14, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -371     |
# | time/              |          |
# |    fps             | 111      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.009243114 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.199      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.73        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0537     |
# |    value_loss           | 17          |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -362.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.583333333333332
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 3          |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.01215731 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | -0.103     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.04       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0604    |
# |    value_loss           | 13.2       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -380.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.979166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 4           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012423418 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0595      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.48        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -300.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.166666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 5           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.014728433 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.00137    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.4         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0615     |
# |    value_loss           | 9.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -234.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.23611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 6           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016044376 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.00811     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.03        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 8.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 43.464285714285715
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 7           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016558183 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00177     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0625     |
# |    value_loss           | 7.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.114583333333336
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 8          |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01702027 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.28      |
# |    explained_variance   | -0.00929   |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.1        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.058     |
# |    value_loss           | 6.49       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.78703703703704
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 9          |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.01830019 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.28      |
# |    explained_variance   | 0.0201     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.996      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0622    |
# |    value_loss           | 5.25       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -208.0
# Standard deviation of reward: 0.0
# Average successful assignments: 63.858333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 10          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019965034 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0029      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.599       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 4.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.21969696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 11          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.021552714 |
# |    clip_fraction        | 0.47        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00476     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.31        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.065      |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.8125
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 12         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02141545 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00499    |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.000545  |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0616    |
# |    value_loss           | 3.63       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.87179487179488
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 13          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.023035295 |
# |    clip_fraction        | 0.51        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00746     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.84        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0626     |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.85714285714286
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 14          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.026246458 |
# |    clip_fraction        | 0.576       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0025      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.81        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0688     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 91.04444444444445
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -370       |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 15         |
# |    time_elapsed         | 175        |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.02538868 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00252    |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.452     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0628    |
# |    value_loss           | 2.9        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.34895833333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 16          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.029046832 |
# |    clip_fraction        | 0.622       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00304     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.183      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0662     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.37254901960785
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -370       |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 17         |
# |    time_elapsed         | 199        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.02892286 |
# |    clip_fraction        | 0.592      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0133     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.42       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0625    |
# |    value_loss           | 2.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 97.02777777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 18          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.029445704 |
# |    clip_fraction        | 0.61        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0543      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0652     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.29824561403508
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 19          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.026094675 |
# |    clip_fraction        | 0.534       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.063      |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 103.15833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 20          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026727209 |
# |    clip_fraction        | 0.548       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.312      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0654     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 105.36904761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 21          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.025804365 |
# |    clip_fraction        | 0.518       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.58        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0644     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 107.78787878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 22          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022750918 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.8695652173913
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 23          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.024031607 |
# |    clip_fraction        | 0.511       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0543      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -108.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.43402777777777
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 24         |
# |    time_elapsed         | 278        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02102957 |
# |    clip_fraction        | 0.434      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.316     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0596    |
# |    value_loss           | 2.76       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.89
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 25          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.023189984 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.57        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0612     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.46474358974359
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 26          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023465049 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.236      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0661     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.53086419753086
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 27          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.020269103 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.0625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 28          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017904371 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.179      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.87931034482759
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 29          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.018374555 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.688       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0585     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.95277777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 30          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019331586 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0579     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.45161290322581
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 31          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.021984065 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.217      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 117.90364583333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 32          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019609801 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.607       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.3030303030303
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 33          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.021148574 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.842       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 120.67401960784314
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 34          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.019163208 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.21       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.96904761904761
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 35          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.023262298 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.54        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0646     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.22222222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 36          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018515814 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.12       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0622     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.39189189189189
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 37          |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017908119 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.265       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0588     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 125.53947368421052
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 38          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017556272 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.993       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0581     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 126.63034188034187
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 39          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.018504415 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.462       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.86666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 40          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019069426 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.452       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0627     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.8211382113821
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 41          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.017468477 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.302       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.75396825396825
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 42          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018331118 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0631     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.63372093023256
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 43          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.017834175 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.174      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.91666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 44          |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018881822 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.774       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0621     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.28333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 45          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.018937724 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.7         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.42        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# ...
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0644     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.85271317829458
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 86          |
# |    time_elapsed         | 1026        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017679662 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0686      |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0683     |
# |    value_loss           | 2.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.21934865900383
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 87          |
# |    time_elapsed         | 1038        |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.017064892 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.698       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.57386363636363
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 88          |
# |    time_elapsed         | 1051        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018906847 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0697     |
# |    value_loss           | 2.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.92696629213484
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 89          |
# |    time_elapsed         | 1063        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.017517466 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.902       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0658     |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.27777777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 90          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018709991 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0657     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.62362637362637
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -356      |
# | time/                   |           |
# |    fps                  | 85        |
# |    iterations           | 91        |
# |    time_elapsed         | 1087      |
# |    total_timesteps      | 93184     |
# | train/                  |           |
# |    approx_kl            | 0.0185267 |
# |    clip_fraction        | 0.37      |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -7.9      |
# |    explained_variance   | 0.432     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.332     |
# |    n_updates            | 900       |
# |    policy_gradient_loss | -0.0695   |
# |    value_loss           | 2.55      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.96376811594203
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -354       |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 92         |
# |    time_elapsed         | 1098       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01675806 |
# |    clip_fraction        | 0.332      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.89      |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.131      |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0688    |
# |    value_loss           | 2.53       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.2983870967742
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 93          |
# |    time_elapsed         | 1109        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.016658816 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.86       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.116       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0669     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.63209219858157
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 94          |
# |    time_elapsed         | 1120        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017916035 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.936       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0725     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.96315789473684
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 95          |
# |    time_elapsed         | 1134        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.019960947 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.665       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0711     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.29600694444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 96          |
# |    time_elapsed         | 1146        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018789107 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.133       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0742     |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.62886597938143
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 97          |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.017189518 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.72       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.342       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0747     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.95493197278913
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -347       |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 98         |
# |    time_elapsed         | 1168       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01661986 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.7       |
# |    explained_variance   | 0.312      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.604      |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.0681    |
# |    value_loss           | 2.43       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.27104377104376
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -346       |
# | time/                   |            |
# |    fps                  | 85         |
# |    iterations           | 99         |
# |    time_elapsed         | 1179       |
# |    total_timesteps      | 101376     |
# | train/                  |            |
# |    approx_kl            | 0.02022768 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.69      |
# |    explained_variance   | 0.337      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.365      |
# |    n_updates            | 980        |
# |    policy_gradient_loss | -0.0726    |
# |    value_loss           | 2.41       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.585
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 100         |
# |    time_elapsed         | 1189        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017657705 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.64       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.512       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0752     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -11.22
# Overall Average Successful Assignments: 126.65241803344894

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -362.0
# Standard deviation of reward: 0.0
# Average successful assignments: 18.166666666666668
# All assignments history: [15, 13, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -372     |
# | time/              |          |
# |    fps             | 106      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -318.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.375
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 94           |
# |    iterations           | 2            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0085674375 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | -0.223       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.65         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0518      |
# |    value_loss           | 18.3         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -354.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.333333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 3           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.011986523 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.202      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.977       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 12.2        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.770833333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 4           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013329405 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0878     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.59        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 9.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -316.0
# Standard deviation of reward: 0.0
# Average successful assignments: 44.833333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 5           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.014231516 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0392     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.16        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 9.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.05555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 6           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014440699 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0282     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0575     |
# |    value_loss           | 8.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.16666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 7           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016542148 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0306     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0632     |
# |    value_loss           | 6.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.01041666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 8           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016787536 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00769     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0581     |
# |    value_loss           | 5.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.78703703703704
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 9           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018616084 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.00217    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.515       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.064      |
# |    value_loss           | 4.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 92.65833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 10          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018181328 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | -0.00465    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.483       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0571     |
# |    value_loss           | 4.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -284.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.79545454545455
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 11          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020896524 |
# |    clip_fraction        | 0.448       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00539     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.492       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0624     |
# |    value_loss           | 3.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 95.27083333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 12         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02112279 |
# |    clip_fraction        | 0.461      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | -0.00235   |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.896      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0591    |
# |    value_loss           | 3.33       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.71794871794872
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 13          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.022948174 |
# |    clip_fraction        | 0.497       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0025      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.603       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.059      |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -376.0
# Standard deviation of reward: 0.0
# Average successful assignments: 92.5
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 14          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023125377 |
# |    clip_fraction        | 0.509       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00117     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.247      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0578     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -366.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.45
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 15          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.024109786 |
# |    clip_fraction        | 0.539       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00294     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.138      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0555     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.859375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 16          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.030061247 |
# |    clip_fraction        | 0.65        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00903     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.69        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0671     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -292.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.70588235294117
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 17          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.030438244 |
# |    clip_fraction        | 0.627       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0591      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.372      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0633     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -304.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.54629629629629
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 18          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.029556267 |
# |    clip_fraction        | 0.599       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0946     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0649     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 76.95175438596492
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 19         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 19456      |
# | train/                  |            |
# |    approx_kl            | 0.02918039 |
# |    clip_fraction        | 0.618      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.168      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.15       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0659    |
# |    value_loss           | 2.78       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -314.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.03333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 20          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.028099615 |
# |    clip_fraction        | 0.563       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.792       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0691     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -304.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.46428571428571
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 21          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.026459059 |
# |    clip_fraction        | 0.547       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0681     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -324.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.67424242424242
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 22          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025485791 |
# |    clip_fraction        | 0.511       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0504     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -302.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.43115942028986
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 23          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.024787579 |
# |    clip_fraction        | 0.517       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.646       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0636     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -224.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.65972222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 24          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021914937 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.58        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -280.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.92333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 25          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.020035189 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.98        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0612     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.30128205128206
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 26          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020260159 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.35       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -200.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.8425925925926
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 27          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.020166986 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.363      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.06       |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -208.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.24404761904762
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -373      |
# | time/                   |           |
# |    fps                  | 86        |
# |    iterations           | 28        |
# |    time_elapsed         | 332       |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0185772 |
# |    clip_fraction        | 0.361     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.26     |
# |    explained_variance   | 0.278     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.594     |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.0537   |
# |    value_loss           | 2.71      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.54310344827586
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 29          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.019958429 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.596       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0569     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -250.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.29444444444445
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 30          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019572612 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -252.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.06451612903226
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 31          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.015939461 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0532     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -294.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.32552083333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 32          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018795973 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.128       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0618     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -254.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.08838383838383
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 33         |
# |    time_elapsed         | 391        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.01729813 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.864      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.06      |
# |    value_loss           | 2.64       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -248.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.96323529411765
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 34          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013618596 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.946       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0528     |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -236.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.99047619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 35          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.016977903 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.127      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0571     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -218.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.23148148148148
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 36          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016392283 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.332      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -220.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.43693693693693
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 37          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.016466042 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0709      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.68640350877193
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 38          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017481703 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0599     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -208.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.98290598290598
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 39          |
# |    time_elapsed         | 463         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.015502643 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.000208    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0579     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.21666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 40          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016052658 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0561     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -220.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.38617886178862
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 41          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.015819088 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.674       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0546     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -206.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.67460317460318
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 42          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014742996 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.198       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0583     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.50581395348837
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 43         |
# |    time_elapsed         | 510        |
# |    total_timesteps      | 44032      |
# | train/                  |            |
# |    approx_kl            | 0.01507994 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.533      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.057     |
# |    value_loss           | 2.5        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.19507575757575
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 44          |
# |    time_elapsed         | 522         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016033255 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.19        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.47        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.9037037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 45          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.014842501 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.543       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -158.0
# ...
# |    value_loss           | 2.27        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.28294573643412
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 86          |
# |    time_elapsed         | 998         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016826209 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.294       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.068      |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.06896551724138
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -362       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 87         |
# |    time_elapsed         | 1011       |
# |    total_timesteps      | 89088      |
# | train/                  |            |
# |    approx_kl            | 0.01503145 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.1       |
# |    explained_variance   | 0.617      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.409      |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.065     |
# |    value_loss           | 2.02       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.83617424242425
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 88          |
# |    time_elapsed         | 1023        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016518492 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.434       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0652     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.60486891385767
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 89          |
# |    time_elapsed         | 1036        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.017436396 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.08       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0883      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0683     |
# |    value_loss           | 1.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.37777777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 90          |
# |    time_elapsed         | 1048        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018466376 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.07       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.496       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0724     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.13736263736264
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 91          |
# |    time_elapsed         | 1060        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.017073922 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.06       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.675       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0688     |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.90126811594203
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 92          |
# |    time_elapsed         | 1072        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.016959794 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.05       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.328       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.067      |
# |    value_loss           | 1.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.67293906810036
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 93          |
# |    time_elapsed         | 1084        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.017691586 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0748     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0699     |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.43794326241135
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 94          |
# |    time_elapsed         | 1098        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017540663 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.5         |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0687     |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.17017543859649
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 95          |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.018118385 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0793     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0712     |
# |    value_loss           | 2.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.88802083333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 96          |
# |    time_elapsed         | 1123        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018629877 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.308       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0691     |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 117.58591065292096
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 97          |
# |    time_elapsed         | 1136        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.018007336 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.212       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0756     |
# |    value_loss           | 2.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.28061224489795
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 98          |
# |    time_elapsed         | 1148        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016532324 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.607       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0694     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.95622895622895
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 99          |
# |    time_elapsed         | 1160        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.018061675 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0772      |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0729     |
# |    value_loss           | 2.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.57916666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 100         |
# |    time_elapsed         | 1172        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.020147916 |
# |    clip_fraction        | 0.429       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.18        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0764     |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -120.52
# Overall Average Successful Assignments: 85.7178652982111

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 10.083333333333334
# All assignments history: [13, 18, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -369     |
# | time/              |          |
# |    fps             | 117      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.291666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.010035658 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.166      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0561     |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -294.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.833333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.013328627 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.185      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.23        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -326.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.604166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014597794 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.93        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -394.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.966666666666665
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 5           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.013326094 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0972      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.86        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 9.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.541666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 6           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014573748 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0796     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.06        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0566     |
# |    value_loss           | 8.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -268.0
# Standard deviation of reward: 0.0
# Average successful assignments: 36.083333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 7           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.017006196 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0431     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 6.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 47.447916666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 8           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017188152 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0251     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.05        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 5.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 52.638888888888886
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -374      |
# | time/                   |           |
# |    fps                  | 100       |
# |    iterations           | 9         |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 9216      |
# | train/                  |           |
# |    approx_kl            | 0.0183254 |
# |    clip_fraction        | 0.387     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.28     |
# |    explained_variance   | 0.00816   |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.17      |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.0592   |
# |    value_loss           | 5.19      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.88333333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 10         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01910078 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00564    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.01       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0582    |
# |    value_loss           | 4.6        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.71969696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 11          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020797461 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00549     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.924       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 3.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.14583333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 101        |
# |    iterations           | 12         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02205602 |
# |    clip_fraction        | 0.481      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00444    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.11       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0615    |
# |    value_loss           | 3.39       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -194.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.31410256410257
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 13          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.022258349 |
# |    clip_fraction        | 0.507       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00477     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.221      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -232.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.1547619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 14          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024698192 |
# |    clip_fraction        | 0.558       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | -0.000581   |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.22222222222223
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 15         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.02525086 |
# |    clip_fraction        | 0.572      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00326    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.618      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0609    |
# |    value_loss           | 2.8        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -290.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.76041666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 16          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.029016942 |
# |    clip_fraction        | 0.62        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00629     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.626       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.066      |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -206.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.54901960784314
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 17         |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.02635159 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.28      |
# |    explained_variance   | 0.0529     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.986      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0575    |
# |    value_loss           | 2.8        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -274.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.71296296296296
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 18          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.028247755 |
# |    clip_fraction        | 0.599       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0852      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0759     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -282.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.7719298245614
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 19          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.027294993 |
# |    clip_fraction        | 0.573       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.78        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0666     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.225
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 20          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027120681 |
# |    clip_fraction        | 0.561       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.83        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0666     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.23809523809524
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 21          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.022644231 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.63        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.67045454545455
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 22         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02147542 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.229      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.797      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0604    |
# |    value_loss           | 2.72       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.84782608695652
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 23          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.022361238 |
# |    clip_fraction        | 0.462       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.685       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.52083333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 24          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021285456 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.894       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.81333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 25          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.019940123 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0596     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.0448717948718
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 26          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018528948 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.312       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0547     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.92283950617283
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -373      |
# | time/                   |           |
# |    fps                  | 105       |
# |    iterations           | 27        |
# |    time_elapsed         | 263       |
# |    total_timesteps      | 27648     |
# | train/                  |           |
# |    approx_kl            | 0.0197795 |
# |    clip_fraction        | 0.395     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.27     |
# |    explained_variance   | 0.269     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.597     |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.0622   |
# |    value_loss           | 2.97      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.03571428571429
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 28          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019249199 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.404       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.67528735632185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 29          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.017943464 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.174      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0614     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.43333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 30          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017348472 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.262       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0586     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 92.34139784946237
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 31          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.016206432 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.177      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0578     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.98177083333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 32          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015924051 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.53        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0537     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 95.79292929292929
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 33          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.015413726 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.19        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 97.57843137254902
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 34          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014930086 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.302       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0555     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.3404761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 35          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.014343804 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.33        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0535     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.82638888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 36          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018346418 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.037       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0599     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 102.53828828828829
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 37          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.019673904 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.419       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.06140350877193
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 38          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017096762 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.1         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0586     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 105.32905982905983
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 39          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.016117971 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.06       |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 106.71666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 40          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016775541 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.32        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0585     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 0.0
# Standard deviation of reward: 0.0
# Average successful assignments: 108.2439024390244
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 41          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.015679877 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.506       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0558     |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.55357142857143
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 42          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017602704 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.04        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0576     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.86627906976744
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 43          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.015292106 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.6590909090909
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 44          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017574975 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.463       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.85185185185185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 45          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.015607789 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.31        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0559     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.84782608695652
# ...
# |    policy_gradient_loss | -0.0756     |
# |    value_loss           | 2.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.03003875968992
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 86          |
# |    time_elapsed         | 805         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020042438 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.95       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.799       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0754     |
# |    value_loss           | 2.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.3668582375479
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 87          |
# |    time_elapsed         | 814         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.018280765 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.207       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.073      |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.72727272727272
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -354       |
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 88         |
# |    time_elapsed         | 824        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01968475 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.88      |
# |    explained_variance   | 0.528      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.371      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0753    |
# |    value_loss           | 2.21       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.09082397003746
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 89          |
# |    time_elapsed         | 833         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.019094119 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.616       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0746     |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.47222222222223
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -352       |
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 90         |
# |    time_elapsed         | 843        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01987376 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.85      |
# |    explained_variance   | 0.571      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.655      |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0767    |
# |    value_loss           | 2.29       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.9010989010989
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -351       |
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 91         |
# |    time_elapsed         | 852        |
# |    total_timesteps      | 93184      |
# | train/                  |            |
# |    approx_kl            | 0.01835816 |
# |    clip_fraction        | 0.394      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.82      |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.639      |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.0787    |
# |    value_loss           | 2.39       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.3913043478261
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 92          |
# |    time_elapsed         | 861         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019270064 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.578       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0757     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.90860215053763
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 93          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.018118441 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.333       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0734     |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.40336879432624
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 94          |
# |    time_elapsed         | 880         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.018294763 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.73       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.323       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0774     |
# |    value_loss           | 2.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.96929824561403
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 95          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.019290302 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.71       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.4         |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0764     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.51388888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 96          |
# |    time_elapsed         | 899         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018440299 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.412       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0773     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.02319587628867
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 97          |
# |    time_elapsed         | 909         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.020123271 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.461       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0772     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.5221088435374
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 98          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018695585 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.65       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.736       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0774     |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.0513468013468
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 99          |
# |    time_elapsed         | 926         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.017112968 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.825       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0737     |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.59333333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -340       |
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 100        |
# |    time_elapsed         | 935        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01921696 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.58      |
# |    explained_variance   | 0.557      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.457      |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0786    |
# |    value_loss           | 2.54       |
# ----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -66.68
# Overall Average Successful Assignments: 105.79481946695574

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 10.5
# All assignments history: [17, 19, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -364     |
# | time/              |          |
# |    fps             | 134      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -330.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008264987 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.192      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.68        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0507     |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -318.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.97222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.011323345 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.127      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.02        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0577     |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -332.0
# Standard deviation of reward: 0.0
# Average successful assignments: 26.916666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012960361 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0317      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.13        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -282.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.766666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 5           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.010957727 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0201     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.23        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.049      |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -300.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.861111111111114
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 6           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014356956 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.00393    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.19        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0575     |
# |    value_loss           | 8.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -298.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.416666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 7           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016242014 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0012      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 6.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -300.0
# Standard deviation of reward: 0.0
# Average successful assignments: 36.458333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 8           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015908903 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0209      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0541     |
# |    value_loss           | 6.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 41.425925925925924
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 9           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018090896 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.000242    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 5.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 47.675
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 10          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020130932 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0184      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.454       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0656     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -142.0
# Standard deviation of reward: 0.0
# Average successful assignments: 53.32575757575758
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 11          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020871744 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00156     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.856       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0648     |
# |    value_loss           | 3.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -344.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.020833333333336
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 12         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02133642 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00762    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.36       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.062     |
# |    value_loss           | 3.29       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.43589743589744
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 13          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.022759086 |
# |    clip_fraction        | 0.512       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.011       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0778     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -320.0
# Standard deviation of reward: 0.0
# Average successful assignments: 53.107142857142854
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 14          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023952099 |
# |    clip_fraction        | 0.537       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0148      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.223      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -204.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.2
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 15          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.026492951 |
# |    clip_fraction        | 0.585       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0218      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.295      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0649     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.609375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 16          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.028038573 |
# |    clip_fraction        | 0.593       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0639      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.84        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0656     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.916666666666664
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 17         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.02481048 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.126      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.234      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0616    |
# |    value_loss           | 2.73       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -258.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.0787037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 18          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025149774 |
# |    clip_fraction        | 0.542       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0726      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0648     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -230.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.80263157894737
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 19          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.026043791 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.87        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0631     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.6375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 20          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022710279 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.61        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0605     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 63.26190476190476
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 21          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.023852132 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.061      |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.25
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 22          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021863967 |
# |    clip_fraction        | 0.421       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.48        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0566     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -182.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.47101449275362
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 23          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.023857724 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0888      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0624     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.69444444444444
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 24         |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02530871 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.325      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.665      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0666    |
# |    value_loss           | 2.65       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.16
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 25          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.021899704 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.922       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -260.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.87179487179488
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 26          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.022216227 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.284      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0639     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -258.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.66666666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 27         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 27648      |
# | train/                  |            |
# |    approx_kl            | 0.02095554 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.382      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.723      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0616    |
# |    value_loss           | 2.55       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -238.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.74702380952381
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 28         |
# |    time_elapsed         | 271        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02271824 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.357      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.97       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0662    |
# |    value_loss           | 2.79       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -226.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.97988505747126
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 29          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.019541569 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.449       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0612     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.83888888888889
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 30         |
# |    time_elapsed         | 288        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01970341 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.404      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0402     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0591    |
# |    value_loss           | 2.52       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.29838709677419
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 31          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.018234212 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.693       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0601     |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.3359375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 32          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018816143 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.59        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -194.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.86363636363636
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 33          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.018419445 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.849       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.4656862745098
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 34          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018609144 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0864      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.25952380952381
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 35         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.01795112 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.425      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.47       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0624    |
# |    value_loss           | 2.54       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.16666666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 36         |
# |    time_elapsed         | 346        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01738688 |
# |    clip_fraction        | 0.335      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.423      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.0693    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0608    |
# |    value_loss           | 2.72       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.64864864864865
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 37          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017983083 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.197      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.21491228070175
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 38          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017598644 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.67        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0587     |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.42948717948718
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 39          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.016027845 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0564     |
# |    value_loss           | 2.42        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.19166666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 40          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016785543 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.14        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.3678861788618
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 41          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.018577222 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.158       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0634     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.90674603174604
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 42         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01697775 |
# |    clip_fraction        | 0.325      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.484      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.00621    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.06      |
# |    value_loss           | 2.43       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.2015503875969
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 43          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.017942019 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.221       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0643     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.19886363636364
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 44          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017306428 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.13        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0601     |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.0425925925926
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 45          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.017429385 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.562       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.34239130434783
# All assignments history: []
# -----------------------------------------
# ...
# |    value_loss           | 2.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.88662790697674
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 86          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.018912196 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.583       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0753     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 132.5756704980843
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 87          |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.019364923 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.95       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.906       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0725     |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.2443181818182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 88          |
# |    time_elapsed         | 804         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.017903445 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.277       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0746     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.86329588014982
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 89          |
# |    time_elapsed         | 813         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.020292785 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.91       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.796       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0766     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.51018518518518
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 90          |
# |    time_elapsed         | 822         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018251013 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.468       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0716     |
# |    value_loss           | 2.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.13919413919413
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 91          |
# |    time_elapsed         | 830         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.018520571 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.732       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0744     |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.79710144927537
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 92          |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018297624 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.87       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.176       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.076      |
# |    value_loss           | 2.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.40591397849462
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 93          |
# |    time_elapsed         | 847         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.017834842 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.567       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0733     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.98758865248226
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 94          |
# |    time_elapsed         | 856         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016584396 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.82       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.789       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0736     |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.5561403508772
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -346      |
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 95        |
# |    time_elapsed         | 864       |
# |    total_timesteps      | 97280     |
# | train/                  |           |
# |    approx_kl            | 0.0188925 |
# |    clip_fraction        | 0.363     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -7.8      |
# |    explained_variance   | 0.61      |
# |    learning_rate        | 0.00018   |
# |    loss                 | 0.0214    |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.0725   |
# |    value_loss           | 2.31      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.11197916666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 96          |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019106805 |
# |    clip_fraction        | 0.434       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.932       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.08       |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.64862542955328
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 97          |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.016230606 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.75       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0561      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0702     |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.18367346938774
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 98          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017613297 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.73       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.00223     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0721     |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.7171717171717
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 99          |
# |    time_elapsed         | 899         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.017496292 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.68       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.347       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0744     |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.24833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 100         |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.018762343 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.65       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.27        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0755     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -72.36
# Overall Average Successful Assignments: 92.3910189431141

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -378.0
# Standard deviation of reward: 0.0
# Average successful assignments: 11.333333333333334
# All assignments history: [8, 18, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -374     |
# | time/              |          |
# |    fps             | 141      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -302.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.416666666666668
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 2          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.00902289 |
# |    clip_fraction        | 0.0684     |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | -0.142     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 3.29       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0528    |
# |    value_loss           | 18.4       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -374.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.694444444444443
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 3            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0126785245 |
# |    clip_fraction        | 0.201        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | -0.0258      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.78         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0633      |
# |    value_loss           | 12.8         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -352.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.5625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013290506 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.0447      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.87        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -358.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.866666666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 5          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.01397788 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | -0.00653   |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.28       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0603    |
# |    value_loss           | 9.44       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -360.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.27777777777778
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -375         |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 6            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0140778255 |
# |    clip_fraction        | 0.232        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | 0.0183       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.08         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0535      |
# |    value_loss           | 8.89         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -242.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.916666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 7           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.016168587 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.041       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.3         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 7.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -322.0
# Standard deviation of reward: 0.0
# Average successful assignments: 28.760416666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 8           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016685463 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0124     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.22        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0584     |
# |    value_loss           | 6.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -370.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.212962962962962
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 9           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018698055 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.00983     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0633     |
# |    value_loss           | 5.3         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -380.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.55
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 10         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01872588 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0104     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.5        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0585    |
# |    value_loss           | 4.78       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.060606060606062
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 11          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020660877 |
# |    clip_fraction        | 0.468       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00511     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0632     |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -368.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.28472222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 12          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021245338 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00842     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.125      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.974358974358974
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 13          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.022965305 |
# |    clip_fraction        | 0.521       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.01        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.16        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0627     |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.154761904761905
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 14          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023836957 |
# |    clip_fraction        | 0.522       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00932     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.39        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0589     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -224.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.24444444444445
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 15          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.026262201 |
# |    clip_fraction        | 0.574       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00953     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.916       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 36.166666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 16          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026286779 |
# |    clip_fraction        | 0.582       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0437      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.57        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 40.166666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 17          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.027315354 |
# |    clip_fraction        | 0.59        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.844       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0627     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -230.0
# Standard deviation of reward: 0.0
# Average successful assignments: 41.97222222222222
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 18         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02626752 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.425      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0656    |
# |    value_loss           | 2.86       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -262.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.925438596491226
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 19          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.024255596 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.37        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -214.0
# Standard deviation of reward: 0.0
# Average successful assignments: 44.80833333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 20         |
# |    time_elapsed         | 173        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02493785 |
# |    clip_fraction        | 0.53       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.897      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0626    |
# |    value_loss           | 2.69       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -238.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.00396825396825
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 21          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.024724733 |
# |    clip_fraction        | 0.508       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.58        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.068      |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -286.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.14772727272727
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 22          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.024444561 |
# |    clip_fraction        | 0.502       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.386       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -260.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.79347826086956
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 23          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.022281863 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.78        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0595     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -190.0
# Standard deviation of reward: 0.0
# Average successful assignments: 48.58680555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 24          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025267087 |
# |    clip_fraction        | 0.525       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.987       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0654     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -244.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.35
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 25          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.023646984 |
# |    clip_fraction        | 0.477       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.38        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0627     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.35897435897436
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 26          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.024295423 |
# |    clip_fraction        | 0.501       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0634     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 53.44135802469136
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 27          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.022221789 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0869      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.36904761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 28          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022801984 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.159      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0635     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 57.27873563218391
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 29         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.02145508 |
# |    clip_fraction        | 0.434      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.306      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.28      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0617    |
# |    value_loss           | 3.01       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -142.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.03333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 30          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021604814 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0632     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -142.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.69086021505376
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 31          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.022303417 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.47        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0643     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 62.135416666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 32          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022048421 |
# |    clip_fraction        | 0.421       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0625     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 63.34848484848485
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 33         |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.02078862 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.347      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.964      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0605    |
# |    value_loss           | 2.62       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -182.0
# Standard deviation of reward: 0.0
# Average successful assignments: 64.23529411764706
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 34          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021563508 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0623     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -128.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.70952380952382
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 35         |
# |    time_elapsed         | 300        |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.02192925 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.39       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.11       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0609    |
# |    value_loss           | 2.66       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.14814814814815
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 36          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018502722 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.241       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.10135135135135
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 37          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.020328559 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0659      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.96929824561404
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 38          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019171622 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.969       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0601     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.70299145299145
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 39          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.019815149 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.19        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.64375
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 40         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01930949 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.25      |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0857     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.063     |
# |    value_loss           | 2.62       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.60162601626017
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 41          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.016499063 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.691       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.71626984126983
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 42         |
# |    time_elapsed         | 359        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01648438 |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.9        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0562    |
# |    value_loss           | 2.7        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.51550387596899
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 43          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.016770894 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.424       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.059      |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.26893939393939
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 44          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017559666 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.155      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.90185185185184
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 45          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.017858207 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.786       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0592     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -68.0
# Standard deviation of reward: 0.0
# ...
# |    value_loss           | 2.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.4108527131783
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 86          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017417587 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.226       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.069      |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.94061302681992
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 87          |
# |    time_elapsed         | 700         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.018292721 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.873       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0689     |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 122.4715909090909
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -354       |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 88         |
# |    time_elapsed         | 706        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01637001 |
# |    clip_fraction        | 0.332      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.97      |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.155      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0671    |
# |    value_loss           | 2.47       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.01310861423221
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 89          |
# |    time_elapsed         | 711         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.016401414 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.477       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0659     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.66203703703704
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 90          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018402923 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.588       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.22161172161172
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 91          |
# |    time_elapsed         | 722         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.017698202 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.91       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.749       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0699     |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.72192028985508
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 92          |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017181054 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0324      |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0686     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 125.37724014336918
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 93          |
# |    time_elapsed         | 732         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.017989568 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.935       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 2.3         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 126.02570921985816
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 94          |
# |    time_elapsed         | 737         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016992033 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.87       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.54        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0749     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 126.63070175438597
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -348       |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 95         |
# |    time_elapsed         | 743        |
# |    total_timesteps      | 97280      |
# | train/                  |            |
# |    approx_kl            | 0.01698209 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.84      |
# |    explained_variance   | 0.409      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.963      |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0761    |
# |    value_loss           | 2.55       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.22309027777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 96          |
# |    time_elapsed         | 748         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018971667 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.8        |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.38        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 2.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.82302405498282
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 97          |
# |    time_elapsed         | 753         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.017092448 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.589       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0731     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.43707482993196
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 98          |
# |    time_elapsed         | 758         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017248146 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0743     |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.02104377104376
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 99          |
# |    time_elapsed         | 763         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.015218293 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.313       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0712     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.63333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 100         |
# |    time_elapsed         | 768         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017040882 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.65       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.434       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0755     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -97.62
# Overall Average Successful Assignments: 83.26043598157635

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -368.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.25
# All assignments history: [13, 10, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -377     |
# | time/              |          |
# |    fps             | 331      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -344.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.916666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008336947 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.212      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.23        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0501     |
# |    value_loss           | 17.4        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.055555555555557
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.012208696 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.128      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.56        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.708333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011984866 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.00866    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.12        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0561     |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -386.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.8
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.013172644 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0178     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.37        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0554     |
# |    value_loss           | 9.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -398.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.65277777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015038142 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0116     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.79        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0583     |
# |    value_loss           | 7.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -376.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.05952380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.015860118 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0582     |
# |    value_loss           | 6.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -248.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.5
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017192539 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.00101    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0612     |
# |    value_loss           | 5.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 39.46296296296296
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.018524103 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.00704    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.767       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 5.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 48.391666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 10          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020186123 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00248     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.02        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0639     |
# |    value_loss           | 4.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 53.35606060606061
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.019349743 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00421     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.826       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.056      |
# |    value_loss           | 3.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -252.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.24305555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021242443 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | -0.00264    |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0804     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0606     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -340.0
# Standard deviation of reward: 0.0
# Average successful assignments: 52.19230769230769
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 13          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.023526648 |
# |    clip_fraction        | 0.528       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00782     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.172      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.67857142857143
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 14         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02462395 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0025     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.304      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0633    |
# |    value_loss           | 2.83       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 60.855555555555554
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 15          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.027808439 |
# |    clip_fraction        | 0.596       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00635     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.579       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0659     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.27604166666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 16          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023966994 |
# |    clip_fraction        | 0.546       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0331      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.12        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0578     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.15196078431373
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 17          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.026890535 |
# |    clip_fraction        | 0.581       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0631      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.154      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.88425925925925
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 18          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025545478 |
# |    clip_fraction        | 0.553       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0349      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0614     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.04824561403508
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.024067499 |
# |    clip_fraction        | 0.495       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.401      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0577     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.65416666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 20          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025124528 |
# |    clip_fraction        | 0.548       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0649     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.07142857142857
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 21          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.023892645 |
# |    clip_fraction        | 0.52        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.367       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0622     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.19318181818181
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 287        |
# |    iterations           | 22         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02494035 |
# |    clip_fraction        | 0.503      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.221      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.174      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0615    |
# |    value_loss           | 2.79       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -128.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.82971014492753
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 23          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.022415414 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.48        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0634     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.28819444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 24          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024296591 |
# |    clip_fraction        | 0.507       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.357       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0651     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 82.35
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 25          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.023378516 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.508       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0618     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.17307692307692
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 26          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020560425 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.931       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.8179012345679
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 27          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.020935923 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.365      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.60119047619048
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 28          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020142792 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.85        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.85632183908046
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 29          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.019575112 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0577     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.8861111111111
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 30         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01626316 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.282      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.76       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0558    |
# |    value_loss           | 2.82       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.1236559139785
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 31         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.01798827 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.269      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.131     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0553    |
# |    value_loss           | 2.83       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 91.84114583333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 32          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019864192 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.545       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0607     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.0580808080808
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 33         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.01720076 |
# |    clip_fraction        | 0.312      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.328      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.2        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0546    |
# |    value_loss           | 2.86       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.8970588235294
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 34          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016427156 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.105       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0549     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 95.17142857142858
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 35          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.016307667 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.557       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0547     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 96.57870370370371
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 36          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016880851 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.197       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.057      |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 97.54054054054055
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 37          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.016529202 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.17        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0603     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -122.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.07894736842105
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 38          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016898867 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.477       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -132.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.47863247863248
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 39          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.015393021 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.396       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 98.79791666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 40          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014371428 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.18        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.051      |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.73373983739837
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 41          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.018317126 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.255       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.87103174603175
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 42          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017129952 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.46124031007751
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 43          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.017522443 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.402       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.058      |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 101.32954545454545
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 44           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0149038015 |
# |    clip_fraction        | 0.29         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -8.24        |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.437        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0585      |
# |    value_loss           | 2.49         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 102.19444444444444
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -371       |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 45         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.01689356 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.354      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.0335     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0618    |
# |    value_loss           | 2.81       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# ...
# |    value_loss           | 2.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.15988372093022
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 86          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.018772332 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.04       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0281      |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.073      |
# |    value_loss           | 1.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.72892720306513
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 87          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.018960698 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.02       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.05        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0724     |
# |    value_loss           | 2.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.29545454545453
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 88          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.017663386 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8          |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.491       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0739     |
# |    value_loss           | 2.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.8380149812734
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 89          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.020077873 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.429       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0751     |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.34259259259258
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 90          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.020849649 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.776       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0787     |
# |    value_loss           | 2.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.86263736263737
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 91          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.019707708 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.105       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0752     |
# |    value_loss           | 2.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.3840579710145
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 92          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017868984 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.999       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.074      |
# |    value_loss           | 2.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.89247311827958
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 93          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.017983355 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.756       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0763     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.39982269503545
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 94          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016992416 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0923      |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0697     |
# |    value_loss           | 1.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.88508771929824
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 95          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.019437786 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.86       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.327       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.076      |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.35850694444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 96          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018310104 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0327      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0746     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.82302405498282
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 97          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.019831002 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.82       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.237       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0786     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.29931972789115
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 98          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019492995 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.8        |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.314       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0788     |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.72895622895624
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 99          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.021106761 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.76       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.255       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.081      |
# |    value_loss           | 2.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.14833333333334
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -349       |
# | time/                   |            |
# |    fps                  | 284        |
# |    iterations           | 100        |
# |    time_elapsed         | 360        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.02093525 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.73      |
# |    explained_variance   | 0.474      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.593      |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0833    |
# |    value_loss           | 2.44       |
# ----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -57.3
# Overall Average Successful Assignments: 102.66951474881351

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
vehicles_df = pd.read_csv('VehicleTrainingDataset_Noisy_0.1.csv')
tasks_df = pd.read_csv('RandomTasks400.csv')

# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.action_space = spaces.Discrete(len(vehicles))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(tasks.shape[1],), dtype=np.float32)
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0  # Reset successful assignments
        #print(f"Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        # Detailed printout of state, action, reward
        
        #lines below can be uncommented for a more detailed output
        #print(f"Task: {task.to_dict()}")
        #print(f"Chosen Vehicle: {vehicle.to_dict()}")
        #print(f"Action: {action}, Reward: {reward}, Done: {done}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1
        
        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -358.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.333333333333332
# All assignments history: [13, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -366     |
# | time/              |          |
# |    fps             | 345      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -352.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.5
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -367       |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.00853461 |
# |    clip_fraction        | 0.0613     |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.29      |
# |    explained_variance   | -0.198     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.74       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0503    |
# |    value_loss           | 16.9       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -380.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.75
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -370      |
# | time/                   |           |
# |    fps                  | 310       |
# |    iterations           | 3         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 3072      |
# | train/                  |           |
# |    approx_kl            | 0.0123908 |
# |    clip_fraction        | 0.193     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -8.29     |
# |    explained_variance   | -0.0251   |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.28      |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0606   |
# |    value_loss           | 11.6      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -386.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.416666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012495099 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.0285     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2           |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0577     |
# |    value_loss           | 10.4        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -390.0
# Standard deviation of reward: 0.0
# Average successful assignments: 13.633333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.014219334 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.00312    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.56        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.06       |
# |    value_loss           | 8.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -360.0
# Standard deviation of reward: 0.0
# Average successful assignments: 14.51388888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015340874 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0123      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.6         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 7.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -378.0
# Standard deviation of reward: 0.0
# Average successful assignments: 14.130952380952381
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -370       |
# | time/                   |            |
# |    fps                  | 303        |
# |    iterations           | 7          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.01684291 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.28      |
# |    explained_variance   | -0.0388    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.26       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0616    |
# |    value_loss           | 6.48       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -310.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.291666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018353466 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.0057      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0634     |
# |    value_loss           | 5.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -370.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.037037037037038
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 9           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.017303295 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | -0.00479    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.97        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0546     |
# |    value_loss           | 5.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -254.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.658333333333335
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 10          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020306472 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.000932    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.185       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.064      |
# |    value_loss           | 4.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -362.0
# Standard deviation of reward: 0.0
# Average successful assignments: 21.303030303030305
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 11          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.020019514 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | -0.00515    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.652       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0598     |
# |    value_loss           | 3.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 27.381944444444443
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 12          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021246333 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.0024      |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.082      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0596     |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.81410256410256
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 13         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.02363924 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.00468    |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.105     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0614    |
# |    value_loss           | 2.95       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -312.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.154761904761905
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 14         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02423881 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0034     |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.167     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0618    |
# |    value_loss           | 2.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -344.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.59444444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 15          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.025331482 |
# |    clip_fraction        | 0.557       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00253     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.069      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0587     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -308.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 16          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.028045494 |
# |    clip_fraction        | 0.618       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.00448     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.216       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -340.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.588235294117645
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 299        |
# |    iterations           | 17         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.02631163 |
# |    clip_fraction        | 0.582      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.0253     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.6        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0582    |
# |    value_loss           | 2.82       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -374.0
# Standard deviation of reward: 0.0
# Average successful assignments: 32.47222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 18          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.024701755 |
# |    clip_fraction        | 0.545       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.098       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.572       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0587     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 31.267543859649123
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 19          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.026763795 |
# |    clip_fraction        | 0.573       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.54        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.065      |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.729166666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 20          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021837864 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.87        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0583     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -184.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.666666666666664
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -373       |
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 21         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.02112686 |
# |    clip_fraction        | 0.432      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.155     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0587    |
# |    value_loss           | 2.78       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -206.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.93181818181818
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 22          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021858826 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0579     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 38.5036231884058
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 23          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.020790035 |
# |    clip_fraction        | 0.451       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0636     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -176.0
# Standard deviation of reward: 0.0
# Average successful assignments: 40.888888888888886
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 24          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021824915 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.19        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0618     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -144.0
# Standard deviation of reward: 0.0
# Average successful assignments: 43.596666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 25          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.021456905 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.22       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0598     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.39102564102564
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 26          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019882629 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.42        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0577     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.407407407407405
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 27          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.020920672 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.216       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0613     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.845238095238095
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 28          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019848613 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.743       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0651     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.07183908045977
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 29          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.021374231 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.156       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0646     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.077777777777776
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 30          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.022532236 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0648     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.51881720430107
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 303        |
# |    iterations           | 31         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.02176813 |
# |    clip_fraction        | 0.431      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.00018    |
# |    loss                 | -0.243     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0635    |
# |    value_loss           | 2.76       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 64.87239583333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 32          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021883935 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.248       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0639     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 68.11616161616162
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 33          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.021396173 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.731       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0647     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 70.48039215686275
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 304        |
# |    iterations           | 34         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01812326 |
# |    clip_fraction        | 0.339      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -8.26      |
# |    explained_variance   | 0.361      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.244      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0589    |
# |    value_loss           | 2.78       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.0904761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 35          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.018208947 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.14       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.9074074074074
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 36          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018064838 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.707       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0616     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 75.52477477477477
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 37          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017023642 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.128       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.09429824561404
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 38          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017068423 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0572     |
# |    value_loss           | 2.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 78.67521367521367
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 39          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.016927533 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.48        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0615     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 81.2125
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 40          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014686027 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.756       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.15853658536585
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 41          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.015108649 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0548     |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 85.1686507936508
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 42          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015452693 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.72        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.84108527131782
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 43          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.013991698 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0777     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0578     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.16287878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 44          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016153416 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 89.82037037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 45          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.015623853 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -8.24       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.31        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0593     |
# |    value_loss           | 2.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 91.19565217391305
# All assignments history: []
# ...
# |    value_loss           | 2.46       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.3468992248062
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 86          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020627338 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0631      |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0724     |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.96168582375478
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 87          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.019094154 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.286       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.071      |
# |    value_loss           | 2.42        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.61174242424244
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 88          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.019805897 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.95       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.39        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0724     |
# |    value_loss           | 2.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.2181647940075
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 89          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.018453777 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.194       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0712     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.85185185185185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 90          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.021134604 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.045       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0706     |
# |    value_loss           | 2.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 139.50274725274724
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 91          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.020683914 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.298       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0706     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.1394927536232
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 92          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018395673 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0708     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.75
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 93          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.020029576 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.584       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0734     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.32358156028369
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 94          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.020418378 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.209       |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0772     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.88070175438597
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 95          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.020619204 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.307       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0753     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.41666666666666
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -346       |
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 96         |
# |    time_elapsed         | 322        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02061122 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -7.75      |
# |    explained_variance   | 0.268      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.05       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0759    |
# |    value_loss           | 2.68       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.9828178694158
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 97          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.022444077 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.73       |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.137       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0738     |
# |    value_loss           | 2.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.5374149659864
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 98          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019311842 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0738     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.12121212121212
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 99          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.019551734 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.074      |
# |    value_loss           | 2.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.67416666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -341        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 100         |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.019192956 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -7.63       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0655      |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0751     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: -61.62
# Overall Average Successful Assignments: 88.9176085799341
