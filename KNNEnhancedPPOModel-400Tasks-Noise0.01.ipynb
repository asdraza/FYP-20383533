# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    X = data.drop(columns=['Eligible'])
    y = data['Eligible']
    return X, y

def optimize_knn_model(X_train, y_train):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    knn_model = KNeighborsRegressor()
    param_grid = {
        'n_neighbors': [3, 5, 10, 20, 30, 40],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan'],
        'p': [1, 2]  # 1: Manhattan distance, 2: Euclidean distance
    }
    grid_search = GridSearchCV(knn_model, param_grid, cv=5, verbose=1, scoring='neg_mean_squared_error')
    grid_search.fit(X_train_scaled, y_train)
    print("Best parameters:", grid_search.best_params_)
    best_knn = grid_search.best_estimator_
    return best_knn, scaler

# Load and train on VehicleTrainingDataset.csv
X_train, y_train = load_and_preprocess_data('VehicleTrainingDataset_Noisy_0.01.csv')
knn_model, scaler = optimize_knn_model(X_train, y_train)

# Predict eligibility scores on 1000VehicleDataset.csv
vehicles_df = pd.read_csv('1000VehicleDataset_Noisy_0.01.csv')
X_test = vehicles_df.drop(columns=['Eligible'])
X_test_scaled = scaler.transform(X_test)
predicted_scores = knn_model.predict(X_test_scaled)

# Assuming you have access to actual scores, replace this line with the actual score loading logic if available
y_actual = vehicles_df['Eligible']

# Replace actual scores with predicted ones
vehicles_df['Eligible'] = predicted_scores  

# Calculate metrics
mae = mean_absolute_error(y_actual, predicted_scores)
rmse = np.sqrt(mean_squared_error(y_actual, predicted_scores))
r_squared = r2_score(y_actual, predicted_scores)
rae = np.sum(np.abs(y_actual - predicted_scores)) / np.sum(np.abs(y_actual - np.mean(y_actual)))

# Output the results
print(f"MAE: {mae}")
print(f"RMSE: {rmse}")
print(f"R-squared: {r_squared}")
print(f"RAE: {rae}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# MAE: 1.7258836094021666
# RMSE: 2.159748576425794
# R-squared: 0.9684512036561819
# RAE: 0.18025169439477964

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -384.0
# Standard deviation of reward: 0.0
# Average successful assignments: 9.0
# All assignments history: [15, 13, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -372     |
# | time/              |          |
# |    fps             | 237      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -368.0
# Standard deviation of reward: 0.0
# Average successful assignments: 12.166666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007189866 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.189      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.28        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -304.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.47222222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.007112027 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.245      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.08        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -276.0
# Standard deviation of reward: 0.0
# Average successful assignments: 30.666666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008518764 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.0581     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.96        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 9.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -282.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.88333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.008483772 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | -0.0627     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.07        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 8.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 47.65277777777778
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 6            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0074044387 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | 0.0451       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.1          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0366      |
# |    value_loss           | 7.78         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -186.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009102948 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.0206     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.63        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 6.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.54166666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 8          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00786179 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.83      |
# |    explained_variance   | 0.0131     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.32       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0345    |
# |    value_loss           | 5.53       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 72.69444444444444
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -365       |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 9          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.00921623 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.82      |
# |    explained_variance   | 0.0133     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.625      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.039     |
# |    value_loss           | 4.57       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.16666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 10          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010091679 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.00684     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.58        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.1969696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 11          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.011416191 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00431     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.87        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3.13        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 94.20833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 12          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012055701 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00103     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 100.8974358974359
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 13          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.011206401 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00669     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.133      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 106.55357142857143
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 14          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014561721 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00685     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.51666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 15          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.013393395 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0115      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.224       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.03125
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 16          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013854653 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0307      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.689       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0533     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 120.12745098039215
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 17          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.011345241 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.076       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 3.73        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.82407407407408
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 18          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010734821 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.085       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.20614035087719
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 19          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.010930531 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.387       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.2375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 20          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009471772 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.36        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.03571428571428
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 21          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009099844 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.36        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0431     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.56439393939394
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 22          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008532334 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.292       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.1340579710145
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -354         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 23           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0066976566 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.197        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0335      |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.63541666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -352         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 24           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0069015166 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.355        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.901        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0368      |
# |    value_loss           | 2.85         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.86666666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -351         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 25           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0069373143 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.386        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.915        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.038       |
# |    value_loss           | 2.78         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.87179487179486
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -349         |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 26           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0066266293 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.439        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0371      |
# |    value_loss           | 3.07         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.070987654321
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 27           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0076123974 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.531        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0394      |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.04464285714286
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 28          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008204212 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0406     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.1206896551724
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -343         |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 29           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0077498313 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.29        |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.23         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0389      |
# |    value_loss           | 2.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.09722222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 30          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007938036 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.839       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.99462365591398
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -337       |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 31         |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.00836196 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.18      |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.744      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0437    |
# |    value_loss           | 2.9        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.80729166666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -335         |
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 32           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0077899136 |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.09        |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.544        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0431      |
# |    value_loss           | 2.94         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.57828282828282
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 33          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.007738008 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.741       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.3921568627451
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 34          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007321704 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.95       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.02        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.06428571428572
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -325         |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 35           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0073142294 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.87        |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.837        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0401      |
# |    value_loss           | 3.59         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.74537037037038
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 36          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006592839 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.863       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.4391891891892
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 37          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007619703 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 3.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.0065789473684
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -315        |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 38          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009202021 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.735       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.047      |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.55555555555554
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -311         |
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 39           |
# |    time_elapsed         | 465          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0071286634 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.53        |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.703        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0434      |
# |    value_loss           | 2.63         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 104.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.04375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 40          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006220935 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.59146341463415
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -304         |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 41           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0072790263 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.41        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0399      |
# |    value_loss           | 2.99         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.984126984127
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 42          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006951593 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.47868217054264
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 43          |
# |    time_elapsed         | 542         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.007031462 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.14        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 122.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.9185606060606
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -293         |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 44           |
# |    time_elapsed         | 562          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0068347035 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.13         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0403      |
# |    value_loss           | 3.03         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.35185185185185
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -289        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 45          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.007401981 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# ...
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.1375968992248
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -63.1        |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 86           |
# |    time_elapsed         | 1398         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0066016824 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.17         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 3.49         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.7375478927203
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -59.9        |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 87           |
# |    time_elapsed         | 1418         |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0059111402 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.543        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.32         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0336      |
# |    value_loss           | 3.57         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.32670454545453
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -56.7      |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 88         |
# |    time_elapsed         | 1441       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00642768 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.529      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.52       |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0364    |
# |    value_loss           | 3.79       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.90262172284645
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -53.6        |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 89           |
# |    time_elapsed         | 1461         |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0063464204 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.64         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0384      |
# |    value_loss           | 3.9          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.43703703703704
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -50.6        |
# | time/                   |              |
# |    fps                  | 62           |
# |    iterations           | 90           |
# |    time_elapsed         | 1483         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0071944688 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.559        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.54         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0345      |
# |    value_loss           | 3.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.9551282051282
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -47.9        |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 91           |
# |    time_elapsed         | 1504         |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0065611936 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.578        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.44         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0317      |
# |    value_loss           | 3.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.45923913043478
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 92          |
# |    time_elapsed         | 1526        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005912884 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.56        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.00089605734766
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -42.7       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 93          |
# |    time_elapsed         | 1547        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006138124 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.08        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 3.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.5195035460993
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -39.5       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 94          |
# |    time_elapsed         | 1568        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006711817 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.62        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 3.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.040350877193
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -37.1     |
# | time/                   |           |
# |    fps                  | 61        |
# |    iterations           | 95        |
# |    time_elapsed         | 1591      |
# |    total_timesteps      | 97280     |
# | train/                  |           |
# |    approx_kl            | 0.0070267 |
# |    clip_fraction        | 0.109     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -3.09     |
# |    explained_variance   | 0.535     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.13      |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.0329   |
# |    value_loss           | 3.47      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.53732638888889
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.7        |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 96           |
# |    time_elapsed         | 1613         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0069625885 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.57         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0367      |
# |    value_loss           | 3.75         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.0266323024055
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -32.7       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 97          |
# |    time_elapsed         | 1633        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.007704554 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.59        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 3.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.50850340136054
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -30.9        |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 98           |
# |    time_elapsed         | 1655         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0063486453 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.45         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0362      |
# |    value_loss           | 3.78         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.97306397306397
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -29.2       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 99          |
# |    time_elapsed         | 1674        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.006405463 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 3.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.4375
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -27.2        |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 100          |
# |    time_elapsed         | 1696         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0055572977 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.04         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0352      |
# |    value_loss           | 4.22         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 83.74
# Overall Average Successful Assignments: 167.3007876236532

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -------- Rollout Summary --------
# Total mean reward: -388.0
# Standard deviation of reward: 0.0
# Average successful assignments: 7.166666666666667
# All assignments history: [11, 15, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -374     |
# | time/              |          |
# |    fps             | 51       |
# |    iterations      | 1        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -210.0
# Standard deviation of reward: 0.0
# Average successful assignments: 44.166666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -375        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 2           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007696669 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.0968     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 17          |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 74.0
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 3            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0075435676 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | -0.119       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.97         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0374      |
# |    value_loss           | 12.6         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.33333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 4           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008491902 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.0545     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.16        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.5
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 5            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0075709806 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | -0.0114      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.21         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0374      |
# |    value_loss           | 8.8          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.625
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -369         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 6            |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0082787685 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | 0.027        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.96         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0371      |
# |    value_loss           | 7.75         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.64285714285714
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 7           |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008858725 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.0134      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.77        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 6.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.53125
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 8           |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009791312 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | -0.00269    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.855       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 5.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.12962962962962
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 9           |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009457343 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 0.004       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 4.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.19166666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 10          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009300368 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00276     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.731       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0391     |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.6818181818182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 11          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010498874 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0031      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.194       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 3.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.95833333333334
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -364       |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 12         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01309002 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.78      |
# |    explained_variance   | 0.00713    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.02       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.051     |
# |    value_loss           | 2.95       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.99358974358975
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 13          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012991969 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0101      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.546       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.99404761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 14          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011791917 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0264      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.79        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.75555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 15          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.011567259 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0777      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.483       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 0.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.94270833333334
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -361         |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 16           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0105780745 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.0987       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0419      |
# |    value_loss           | 2.83         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.10294117647058
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 17          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.011237875 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.21759259259258
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 18          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012098573 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.65        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.24561403508773
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 19          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009936357 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.941       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.14583333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 20          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009767786 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 21          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.010219301 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.541       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.90151515151516
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 22          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009946541 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.794       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.72101449275362
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 23          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009121144 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.216       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.46875
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -349       |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 24         |
# |    time_elapsed         | 500        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00852935 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | 0.22       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.707      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0446    |
# |    value_loss           | 3.15       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.11
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -347       |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 25         |
# |    time_elapsed         | 518        |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.00916021 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.46      |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.4        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0442    |
# |    value_loss           | 2.95       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 22.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.06089743589743
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 26          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009390842 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.431       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.0648148148148
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 27          |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008888787 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.719       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.06845238095238
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 28          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009327959 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.725       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.05747126436782
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 29          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.009688794 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.86        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.048      |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.025
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 30          |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008723556 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.825       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.05913978494624
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -333        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 31          |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008589111 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.36        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 3.41        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.33854166666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 32          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008504369 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.07       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.848       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.5479797979798
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 33          |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008796575 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.74019607843138
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 34          |
# |    time_elapsed         | 693         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008082647 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.10476190476192
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -320       |
# | time/                   |            |
# |    fps                  | 50         |
# |    iterations           | 35         |
# |    time_elapsed         | 712        |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.00813069 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.81      |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.1        |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0482    |
# |    value_loss           | 3.25       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.3726851851852
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 36          |
# |    time_elapsed         | 731         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008357557 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.76       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.893       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.65765765765767
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 37          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.008791325 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.602       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.86622807017545
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -312         |
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 38           |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0078223385 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0.515        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.15         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0475      |
# |    value_loss           | 3.14         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.18803418803418
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 39          |
# |    time_elapsed         | 791         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008472658 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.43125
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -305        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 40          |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008534198 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.909       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 104.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.66666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -302        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 41          |
# |    time_elapsed         | 829         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.007768106 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.59        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 180.96825396825398
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -298        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 42          |
# |    time_elapsed         | 849         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008570278 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 182.3391472868217
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -295         |
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 43           |
# |    time_elapsed         | 868          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0086057745 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.945        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0466      |
# |    value_loss           | 3            |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 183.53787878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 44          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008792201 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 184.63148148148147
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 45          |
# |    time_elapsed         | 906         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008900475 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.808       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# ...
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -79.2        |
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 86           |
# |    time_elapsed         | 1670         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0055605667 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.59         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0323      |
# |    value_loss           | 3.61         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.05555555555554
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -75.6        |
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 87           |
# |    time_elapsed         | 1688         |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0066200355 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.23         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0359      |
# |    value_loss           | 3.81         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.58617424242425
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -71.7        |
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 88           |
# |    time_elapsed         | 1705         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0046388465 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.76         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0302      |
# |    value_loss           | 3.54         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.1067415730337
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 89          |
# |    time_elapsed         | 1723        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.006572907 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0343     |
# |    value_loss           | 3.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.62962962962962
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -64.7      |
# | time/                   |            |
# |    fps                  | 52         |
# |    iterations           | 90         |
# |    time_elapsed         | 1741       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00630557 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.494      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.27       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0342    |
# |    value_loss           | 3.39       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.13553113553112
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -61.3       |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 91          |
# |    time_elapsed         | 1759        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.006572469 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.032      |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.64039855072463
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -58.3        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 92           |
# |    time_elapsed         | 1777         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0067176158 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.2          |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0355      |
# |    value_loss           | 3.65         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.1442652329749
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -55.4        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 93           |
# |    time_elapsed         | 1794         |
# |    total_timesteps      | 95232        |
# | train/                  |              |
# |    approx_kl            | 0.0064668544 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.59         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0339      |
# |    value_loss           | 3.67         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.64007092198582
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 94           |
# |    time_elapsed         | 1810         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0066566067 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.511        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.5          |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0325      |
# |    value_loss           | 3.54         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 172.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.12719298245614
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 95          |
# |    time_elapsed         | 1828        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.006298458 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 3.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.59027777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -47.7       |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 96          |
# |    time_elapsed         | 1845        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006996015 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 3.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.05498281786942
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -45.3        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 97           |
# |    time_elapsed         | 1863         |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0066646575 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 3.28         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.5297619047619
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -42.8        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 98           |
# |    time_elapsed         | 1880         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0064094784 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.91         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 3.8          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.9814814814815
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -40.1        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 99           |
# |    time_elapsed         | 1898         |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0070197973 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.535        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.4          |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.037       |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.41166666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -38.1        |
# | time/                   |              |
# |    fps                  | 53           |
# |    iterations           | 100          |
# |    time_elapsed         | 1915         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063648676 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.46         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0293      |
# |    value_loss           | 3.25         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 94.36
# Overall Average Successful Assignments: 182.29868415431173

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -386.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.083333333333334
# All assignments history: [13, 14, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    fps             | 64       |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.958333333333334
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 2            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0077928966 |
# |    clip_fraction        | 0.0876       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.87        |
# |    explained_variance   | -0.204       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.95         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0404      |
# |    value_loss           | 18           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -358.0
# Standard deviation of reward: 0.0
# Average successful assignments: 12.472222222222221
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 3           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008268302 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.92        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 13          |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.75
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 4           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007818171 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | -0.122      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.94        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.038      |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 34.88333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 5           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.007369999 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | -0.0152     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.38        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 9.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 55.02777777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 6           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008611701 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.0167     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.98        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 7.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.05952380952381
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -368      |
# | time/                   |           |
# |    fps                  | 60        |
# |    iterations           | 7         |
# |    time_elapsed         | 119       |
# |    total_timesteps      | 7168      |
# | train/                  |           |
# |    approx_kl            | 0.0082567 |
# |    clip_fraction        | 0.137     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.83     |
# |    explained_variance   | -0.0381   |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.36      |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.0383   |
# |    value_loss           | 6.3       |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.1875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 8           |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008743752 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.00728     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 5.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.62962962962963
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -367       |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 9          |
# |    time_elapsed         | 153        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.00948141 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.81      |
# |    explained_variance   | 0.00337    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.633      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0394    |
# |    value_loss           | 4.56       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.475
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 10          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010416912 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | -0.0025     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 101.43181818181819
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 11          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010701193 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00922     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.86        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 106.77777777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 12          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011280601 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.556       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.33974358974359
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 13          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012797653 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.333       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 115.49404761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 14          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013978075 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.581       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 120.30555555555556
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 15          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012796441 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0742      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.85        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.53645833333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 16           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0101314895 |
# |    clip_fraction        | 0.199        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.75        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.46         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0433      |
# |    value_loss           | 2.93         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.59803921568627
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 17          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010198621 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.12962962962962
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 18          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010803979 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.161       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.28508771929825
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 19          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009064911 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.05416666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -356         |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 20           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0082264785 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1            |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0401      |
# |    value_loss           | 3.08         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.51984126984127
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 21          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008847971 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.68        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.043      |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.88257575757575
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 22          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008752072 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.61        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.66666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 23          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009258785 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0451     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.23611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 24          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009191595 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.466       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.56666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 25          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.009639185 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.523       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.64743589743588
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -346       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 26         |
# |    time_elapsed         | 454        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00926126 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.51      |
# |    explained_variance   | 0.351      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.66       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0472    |
# |    value_loss           | 3.2        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.59259259259258
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 27          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.009588893 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.5
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 28          |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009567202 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.27298850574712
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 29          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.009670321 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.63        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0497     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.1611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 30          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010426762 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.13        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0516     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.747311827957
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 31          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.007527822 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.894       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.37760416666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -333        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 32          |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008455841 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.771       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.82323232323233
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 33          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.009057206 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.14       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.64        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.27941176470588
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 34          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009633814 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.725       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0536     |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 104.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.76190476190476
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 35          |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008849183 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.756       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.23842592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 36          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008754225 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.741       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 104.0
# Standard deviation of reward: 0.0
# Average successful assignments: 176.61486486486487
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 37          |
# |    time_elapsed         | 646         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.009652606 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0514     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 108.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.00438596491227
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -315        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 38          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009347561 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.899       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0491     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.23717948717947
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -312        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 39          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.009769112 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.981       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 180.4875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -309        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 40          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007863753 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.08        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 181.77439024390245
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -305        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 41          |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008944277 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.835       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 182.9920634920635
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -301       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 42         |
# |    time_elapsed         | 731        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00825507 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.648      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.28       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.046     |
# |    value_loss           | 3.26       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 184.13565891472868
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -298        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 43          |
# |    time_elapsed         | 749         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.007146627 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 3.45        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 185.2973484848485
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -295       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 44         |
# |    time_elapsed         | 766        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00759943 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.67       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.26       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0488    |
# |    value_loss           | 3.23       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 186.4425925925926
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -291         |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 45           |
# |    time_elapsed         | 785          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0072575323 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.11         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0441      |
# |    value_loss           | 3.29         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# ...
# Average successful assignments: 220.53100775193798
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -64.3        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 86           |
# |    time_elapsed         | 1505         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0071432907 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.11         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0378      |
# |    value_loss           | 3.07         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.066091954023
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -60.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 87           |
# |    time_elapsed         | 1523         |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0066875615 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.06         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0418      |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.5785984848485
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -56.5        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 88           |
# |    time_elapsed         | 1540         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0065232376 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0367      |
# |    value_loss           | 3.29         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.07865168539325
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -52.5      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 89         |
# |    time_elapsed         | 1555       |
# |    total_timesteps      | 91136      |
# | train/                  |            |
# |    approx_kl            | 0.00651969 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.436      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.997      |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.0366    |
# |    value_loss           | 3.01       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.55277777777778
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -49.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 90           |
# |    time_elapsed         | 1574         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0068429955 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.49         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.945        |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0339      |
# |    value_loss           | 2.8          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.03571428571428
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -46          |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 91           |
# |    time_elapsed         | 1594         |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0062930547 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.69         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.04        |
# |    value_loss           | 3.71         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.49728260869566
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -42.7        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 92           |
# |    time_elapsed         | 1612         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0056644357 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.25         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.0346      |
# |    value_loss           | 3.27         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.96326164874552
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 93          |
# |    time_elapsed         | 1632        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006723227 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 3.25        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.42375886524823
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -36.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 94           |
# |    time_elapsed         | 1650         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0071482495 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.05         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0391      |
# |    value_loss           | 2.78         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.83771929824562
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 95           |
# |    time_elapsed         | 1669         |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0070134145 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.16         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0379      |
# |    value_loss           | 3.01         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.25173611111111
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -31.4        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 96           |
# |    time_elapsed         | 1688         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0076246583 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.94         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0377      |
# |    value_loss           | 3.03         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.65807560137458
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 97          |
# |    time_elapsed         | 1707        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.006917076 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.36        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.05102040816325
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -27.3      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 98         |
# |    time_elapsed         | 1726       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00652683 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.3        |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.0393    |
# |    value_loss           | 3.23       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.4520202020202
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 99          |
# |    time_elapsed         | 1745        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.006728465 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.8375
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -22.9        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 100          |
# |    time_elapsed         | 1764         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063730953 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.07         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0401      |
# |    value_loss           | 3.03         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 94.0
# Overall Average Successful Assignments: 175.04849395426933

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -374.0
# Standard deviation of reward: 0.0
# Average successful assignments: 13.833333333333334
# All assignments history: [16, 20, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -364     |
# | time/              |          |
# |    fps             | 62       |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -224.0
# Standard deviation of reward: 0.0
# Average successful assignments: 44.958333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007979611 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.186      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -312.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.916666666666664
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 3            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0082487175 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | -0.109       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.57         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0399      |
# |    value_loss           | 10.4         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -264.0
# Standard deviation of reward: 0.0
# Average successful assignments: 47.083333333333336
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 4            |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0075750416 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | 0.0127       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.04         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0366      |
# |    value_loss           | 9.67         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 58.6
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 5           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.008030242 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | 0.0249      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.99        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0378     |
# |    value_loss           | 8.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -134.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.81944444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 6           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008407002 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.0296     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.96        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 7.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.25
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -367         |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 7            |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0092843305 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.83        |
# |    explained_variance   | -0.005       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.07         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0402      |
# |    value_loss           | 5.81         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 88.10416666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 8           |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008585963 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.000662    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.61        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0378     |
# |    value_loss           | 5.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 97.42592592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 9           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.010280052 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.00201     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 4.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.85
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 10          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009867515 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00706     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.618       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 111.03787878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 11          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010027764 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00813     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.276       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 3.2         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.15972222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 12          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012704573 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00513     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.588       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 120.91666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 13          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.013440661 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.009       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.9702380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 14          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013243734 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.314       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0451     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.44444444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 15          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012111828 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0377      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0487     |
# |    value_loss           | 2.95        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.39583333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 16          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009808449 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0877      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.9264705882353
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 17          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010872311 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.639       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 14.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.33333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 18          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008618778 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.802       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.4517543859649
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -356         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 19           |
# |    time_elapsed         | 352          |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0094976425 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.862        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0428      |
# |    value_loss           | 2.82         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.575
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 20          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009664189 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.158       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.61507936507937
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 21          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008063539 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1           |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.41287878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 22          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007851718 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.183       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.2826086956522
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 23          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.008486992 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.66        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0442     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.19791666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -350         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 24           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0088133495 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.53        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.821        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0429      |
# |    value_loss           | 2.92         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.10666666666665
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -348         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 25           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0066015422 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.49        |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.77         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0362      |
# |    value_loss           | 3.07         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.91666666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 26           |
# |    time_elapsed         | 482          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0074148215 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.42        |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.414        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0419      |
# |    value_loss           | 2.68         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.78703703703704
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -345         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 27           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0086801415 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.621        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.044       |
# |    value_loss           | 2.73         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.45833333333334
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -342         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 28           |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0078049884 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.31        |
# |    explained_variance   | 0.374        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.709        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0417      |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.32471264367817
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 29          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.007767015 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.1
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -337         |
# | time/                   |              |
# |    fps                  | 55           |
# |    iterations           | 30           |
# |    time_elapsed         | 558          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0070704697 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.17         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0404      |
# |    value_loss           | 3.34         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.9005376344086
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 31          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.007686099 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.24        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.72395833333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 32          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007855875 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.841       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.39646464646464
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -329        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 33          |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008343561 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.38        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.10049019607843
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -326        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 34          |
# |    time_elapsed         | 634         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008590197 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.87       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.57        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.81428571428572
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -323         |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 35           |
# |    time_elapsed         | 652          |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0073171062 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.77        |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.65         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0418      |
# |    value_loss           | 3.69         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.49074074074073
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -319        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 36          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007477705 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.8         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 3.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.20495495495496
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -316         |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 37           |
# |    time_elapsed         | 691          |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0087965075 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.36         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0455      |
# |    value_loss           | 3.44         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.8267543859649
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -312        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 38          |
# |    time_elapsed         | 710         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008415652 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.54        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 3.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.3846153846154
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -309        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 39          |
# |    time_elapsed         | 729         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008769985 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.95208333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -305        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 40          |
# |    time_elapsed         | 748         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008774315 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0451     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.47764227642276
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -301       |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 41         |
# |    time_elapsed         | 766        |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.00868557 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.24      |
# |    explained_variance   | 0.556      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.29       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.046     |
# |    value_loss           | 3.35       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.90674603174602
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -298        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 42          |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008186616 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 112.0
# Standard deviation of reward: 0.0
# Average successful assignments: 180.24031007751938
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 43          |
# |    time_elapsed         | 804         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.008434111 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 181.6193181818182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -289        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 44          |
# |    time_elapsed         | 823         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008302409 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 182.87777777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -286        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 45          |
# |    time_elapsed         | 842         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008298929 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.00018     |
# ...
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.68701550387595
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -61.9       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 86          |
# |    time_elapsed         | 1607        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006252708 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.381       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.26        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.17337164750958
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -58.6      |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 87         |
# |    time_elapsed         | 1628       |
# |    total_timesteps      | 89088      |
# | train/                  |            |
# |    approx_kl            | 0.00559609 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.49       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0309    |
# |    value_loss           | 2.84       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.6657196969697
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -55          |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 88           |
# |    time_elapsed         | 1647         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0065063387 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.381        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.852        |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0393      |
# |    value_loss           | 2.68         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.14232209737827
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -51.4       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 89          |
# |    time_elapsed         | 1666        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.005710245 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.984       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.5962962962963
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 90          |
# |    time_elapsed         | 1685        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006215049 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.694       |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.04212454212455
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -45.7       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 91          |
# |    time_elapsed         | 1704        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.005378452 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.6         |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 3.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.48460144927537
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -42.9      |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 92         |
# |    time_elapsed         | 1723       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00662022 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.417      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.06       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0338    |
# |    value_loss           | 3.23       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 148.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.9247311827957
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -40.4       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 93          |
# |    time_elapsed         | 1740        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.007050487 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.31        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 3.53        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.34751773049646
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -38.9        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 94           |
# |    time_elapsed         | 1757         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0064658467 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.404        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.27         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0359      |
# |    value_loss           | 3.41         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.7736842105263
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -36.6       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 95          |
# |    time_elapsed         | 1775        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.006743118 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 3.3         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.18055555555554
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.8        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 96           |
# |    time_elapsed         | 1792         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0055243457 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.4          |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0422      |
# |    value_loss           | 2.95         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.58591065292097
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -32.7        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 97           |
# |    time_elapsed         | 1810         |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0065994663 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.29         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0356      |
# |    value_loss           | 3.3          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.98469387755102
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -31.3       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 98          |
# |    time_elapsed         | 1828        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006304918 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.72        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.3872053872054
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -29.7        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 99           |
# |    time_elapsed         | 1845         |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0061987434 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.38         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.5          |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0424      |
# |    value_loss           | 3.49         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.77416666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -28.1        |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 100          |
# |    time_elapsed         | 1863         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0077215116 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.05         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.037       |
# |    value_loss           | 2.69         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 86.58
# Overall Average Successful Assignments: 174.58997947629493

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -366.0
# Standard deviation of reward: 0.0
# Average successful assignments: 16.5
# All assignments history: [15, 13, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -372     |
# | time/              |          |
# |    fps             | 63       |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -274.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007068443 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.211      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 4.12        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.16666666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -373         |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 3            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0072590336 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.0309       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.43         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0393      |
# |    value_loss           | 13.9         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -246.0
# Standard deviation of reward: 0.0
# Average successful assignments: 66.4375
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 4            |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0066358997 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | 0.0835       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.17         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0352      |
# |    value_loss           | 11.2         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 80.21666666666667
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -367      |
# | time/                   |           |
# |    fps                  | 59        |
# |    iterations           | 5         |
# |    time_elapsed         | 85        |
# |    total_timesteps      | 5120      |
# | train/                  |           |
# |    approx_kl            | 0.0073344 |
# |    clip_fraction        | 0.0948    |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.85     |
# |    explained_variance   | -0.0794   |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.91      |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0392   |
# |    value_loss           | 9.02      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.34722222222223
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 6           |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008708553 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.74        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 7.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 0.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.23809523809524
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 7           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008066816 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.0159      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.71        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0386     |
# |    value_loss           | 6.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 112.44791666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 8           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009418981 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | -0.0101     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.57        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0404     |
# |    value_loss           | 5.52        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.02777777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 9           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008771272 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.0103      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 5.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 12.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.575
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -366         |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 10           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0090427175 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.8         |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.941        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0401      |
# |    value_loss           | 4.09         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.9848484848485
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 11          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010128406 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00443     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.813       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0406     |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.70833333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 12          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012247294 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00638     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.76282051282053
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 13          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012977235 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00183     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.515       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.19642857142858
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 14          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011877388 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00459     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.893       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.31666666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -362         |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 15           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0150452005 |
# |    clip_fraction        | 0.275        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.78        |
# |    explained_variance   | 0.00486      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.37         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0486      |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 147.921875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 16          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010470532 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0417      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.44607843137254
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 17           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0096325185 |
# |    clip_fraction        | 0.208        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.76        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.18         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0464      |
# |    value_loss           | 2.87         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.74074074074073
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 18          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007955778 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.29        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0402     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.78070175438597
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 19          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009724491 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.73333333333332
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -357       |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 20         |
# |    time_elapsed         | 359        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00850784 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.7       |
# |    explained_variance   | 0.217      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.84       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0422    |
# |    value_loss           | 2.71       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.63888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 21          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008146866 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.45075757575756
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 22          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009067068 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.98        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.17753623188406
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 23          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.007009952 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.3         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.65277777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 24          |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009034501 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.353       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.95666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 25          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.007959415 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.688       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.28205128205127
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 26          |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007487299 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.733       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.6141975308642
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 27          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008176627 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.95        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.8452380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 28          |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008156972 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.981       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 3.27        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.01149425287358
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -342         |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 29           |
# |    time_elapsed         | 525          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0094499225 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.35        |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.404        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0475      |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.15277777777777
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -340         |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 30           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0086982455 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.3         |
# |    explained_variance   | 0.313        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.764        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0469      |
# |    value_loss           | 2.93         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.36559139784947
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 31          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008525857 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.5859375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 32          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008813253 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2           |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 174.75757575757575
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -332         |
# | time/                   |              |
# |    fps                  | 56           |
# |    iterations           | 33           |
# |    time_elapsed         | 599          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0084450515 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.1         |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.752        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0477      |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.94117647058823
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -329        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 34          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008906178 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.927       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.1
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -326        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 35          |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009007951 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.885       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.21990740740742
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -323       |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 36         |
# |    time_elapsed         | 653        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00808437 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.87      |
# |    explained_variance   | 0.281      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.871      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 3.01       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.31981981981983
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -320        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 37          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007950133 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.99        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 180.4232456140351
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 38          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008996837 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0517     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 181.47435897435898
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -313        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 39          |
# |    time_elapsed         | 708         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.009290386 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.971       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0442     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 182.61041666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -310        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 40          |
# |    time_elapsed         | 726         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008168679 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 183.91056910569105
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -307        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 41          |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008444928 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0498     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 185.1547619047619
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 42          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008935835 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0505     |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 130.0
# Standard deviation of reward: 0.0
# Average successful assignments: 186.484496124031
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -300       |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 43         |
# |    time_elapsed         | 781        |
# |    total_timesteps      | 44032      |
# | train/                  |            |
# |    approx_kl            | 0.01027382 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.27       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0501    |
# |    value_loss           | 3          |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 187.68371212121212
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 44          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009087892 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.993       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 3.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 188.86296296296297
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -293        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 45          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008063785 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.944       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0499     |
# |    value_loss           | 2.89        |
# ...
# Average successful assignments: 223.75387596899225
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -71.5      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 86         |
# |    time_elapsed         | 1504       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00633983 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.38       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.882      |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0389    |
# |    value_loss           | 2.88       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.2404214559387
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -67.6        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 87           |
# |    time_elapsed         | 1520         |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0063069267 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.22         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0393      |
# |    value_loss           | 2.73         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 224.72348484848484
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -64.1        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 88           |
# |    time_elapsed         | 1537         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0066570146 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.879        |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0344      |
# |    value_loss           | 2.5          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.20131086142322
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -60.9        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 89           |
# |    time_elapsed         | 1552         |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0068263216 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.3         |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.09         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0341      |
# |    value_loss           | 2.93         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 225.66944444444445
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -57.8        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 90           |
# |    time_elapsed         | 1567         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0076918416 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.29         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0445      |
# |    value_loss           | 2.91         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.15384615384616
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -54.5        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 91           |
# |    time_elapsed         | 1582         |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0074651497 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.14         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0418      |
# |    value_loss           | 3.09         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 226.64039855072463
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -51.5        |
# | time/                   |              |
# |    fps                  | 58           |
# |    iterations           | 92           |
# |    time_elapsed         | 1598         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0054301256 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.13         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.038       |
# |    value_loss           | 3            |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 227.11290322580646
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 93          |
# |    time_elapsed         | 1614        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.005582977 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.38        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 227.56914893617022
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -46          |
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 94           |
# |    time_elapsed         | 1627         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0059108576 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.14        |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.34         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0405      |
# |    value_loss           | 3.12         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 228.02894736842106
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -43.5       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 95          |
# |    time_elapsed         | 1641        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.007316852 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 228.46875
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -41.2        |
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 96           |
# |    time_elapsed         | 1655         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0062858094 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.1         |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.77         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0391      |
# |    value_loss           | 3.7          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 228.90893470790377
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -39          |
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 97           |
# |    time_elapsed         | 1669         |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0057640504 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.08        |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.24         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0386      |
# |    value_loss           | 3.1          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 229.33928571428572
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -36.6       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 98          |
# |    time_elapsed         | 1684        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007053787 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.04        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 178.0
# Standard deviation of reward: 0.0
# Average successful assignments: 229.7996632996633
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -34.2       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 99          |
# |    time_elapsed         | 1697        |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.006547695 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 174.0
# Standard deviation of reward: 0.0
# Average successful assignments: 230.2225
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -32.2       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 100         |
# |    time_elapsed         | 1712        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005979627 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 103.22
# Overall Average Successful Assignments: 183.92980971990156

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -370.0
# Standard deviation of reward: 0.0
# Average successful assignments: 14.916666666666666
# All assignments history: [19, 10, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -371     |
# | time/              |          |
# |    fps             | 81       |
# |    iterations      | 1        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -356.0
# Standard deviation of reward: 0.0
# Average successful assignments: 17.541666666666668
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -374       |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 2          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.00943508 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.87      |
# |    explained_variance   | -0.205     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.56       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0447    |
# |    value_loss           | 16.3       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -332.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.194444444444443
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 3            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0085760355 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | -0.0188      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.17         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.04        |
# |    value_loss           | 12.4         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 19.041666666666668
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 4           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008469567 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.99        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0392     |
# |    value_loss           | 9.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -348.0
# Standard deviation of reward: 0.0
# Average successful assignments: 20.15
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -370       |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 5          |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.00803792 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.85      |
# |    explained_variance   | -0.0267    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.36       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0366    |
# |    value_loss           | 9.04       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -312.0
# Standard deviation of reward: 0.0
# Average successful assignments: 23.458333333333332
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -368      |
# | time/                   |           |
# |    fps                  | 74        |
# |    iterations           | 6         |
# |    time_elapsed         | 82        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0086977 |
# |    clip_fraction        | 0.14      |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.84     |
# |    explained_variance   | 0.0264    |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.83      |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.0399   |
# |    value_loss           | 7.4       |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 39.083333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 7           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009300221 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | -0.0093     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.19        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 6.27        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 50.864583333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 8           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009703727 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.0238      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.5         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 5.29        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 61.52777777777778
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 9           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008817803 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00157     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 4.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.41666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 10          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011409399 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | -0.00218    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.477       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -20.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.60606060606061
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 11          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.011135764 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | -0.00037    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.674       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 87.02083333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 12          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011197825 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00237     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0426      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 93.28846153846153
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 13          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.014447153 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00298     |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.124      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 16.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.38095238095238
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -359       |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 14         |
# |    time_elapsed         | 193        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01410299 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.76      |
# |    explained_variance   | 0.0119     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.735      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0476    |
# |    value_loss           | 2.72       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.90555555555555
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 15          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012746842 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0596      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 18.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.50520833333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 16          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010977443 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0863      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.239       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.4656862745098
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 17          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010080922 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.083       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.851       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.98        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 117.56481481481481
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -355       |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 18         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00964279 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.69      |
# |    explained_variance   | 0.101      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.11       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.044     |
# |    value_loss           | 2.9        |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.33771929824562
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 19          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.010575995 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.928       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.82916666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 20          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009123187 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.01        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.76984126984127
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 21          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009658682 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.526       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 130.58712121212122
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 22          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008953363 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.231884057971
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 23          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009313512 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.88        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.86111111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 24          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008996446 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.13        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.15
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 25          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.009170262 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.44551282051282
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 26          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008610394 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.571       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.65123456790124
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 27          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008149469 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.638       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0396     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.6279761904762
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 28          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007456517 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.28       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.626       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0391     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.566091954023
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -335        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 29          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.009213017 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.22       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.3972222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -331        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 30          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008070565 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.99193548387098
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -328         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 31           |
# |    time_elapsed         | 432          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0074221673 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.06        |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.54         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0374      |
# |    value_loss           | 3.15         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.52083333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 32          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008147022 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.17171717171718
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -322         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 33           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0082922205 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.89        |
# |    explained_variance   | 0.626        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.01         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0418      |
# |    value_loss           | 3.22         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.6642156862745
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -319        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 34          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007959422 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.832       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 3.38        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.14761904761906
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 35          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008431231 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.941       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.71296296296296
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -312         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 36           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0077066636 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.622        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.039       |
# |    value_loss           | 2.37         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.23873873873873
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -310         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 37           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0063228053 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.69        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.79         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.037       |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.7434210526316
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -307        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 38          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007325386 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.633       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 2.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.1559829059829
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -303         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 39           |
# |    time_elapsed         | 546          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0072077876 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.95         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0425      |
# |    value_loss           | 2.94         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.52708333333334
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -300       |
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 40         |
# |    time_elapsed         | 560        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00806313 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.47      |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.36       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0408    |
# |    value_loss           | 2.92       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.8150406504065
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -296         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 41           |
# |    time_elapsed         | 574          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0066356207 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.886        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.038       |
# |    value_loss           | 3.11         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.06944444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -293        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 42          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007310168 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.2751937984496
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 43           |
# |    time_elapsed         | 603          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0071748924 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.31         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0397      |
# |    value_loss           | 2.92         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.46401515151516
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 44          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007636853 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.6240740740741
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -285        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 45          |
# |    time_elapsed         | 630         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.005683095 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 3.25        |
# ...
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -86.3        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 86           |
# |    time_elapsed         | 1220         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0056248605 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.95         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0354      |
# |    value_loss           | 3.66         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 206.70114942528735
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -81.9        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 87           |
# |    time_elapsed         | 1234         |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0070354985 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.38         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0349      |
# |    value_loss           | 3.33         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.32575757575756
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 88          |
# |    time_elapsed         | 1246        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005508812 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.64        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 3.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 207.9307116104869
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -75         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 89          |
# |    time_elapsed         | 1259        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.006038381 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.37        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 3.27        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 208.52314814814815
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -72          |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 90           |
# |    time_elapsed         | 1272         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0069522597 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.44         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0363      |
# |    value_loss           | 3.19         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 209.0952380952381
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -69.5        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 91           |
# |    time_elapsed         | 1285         |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0068534175 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.53         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0364      |
# |    value_loss           | 3.71         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 209.6413043478261
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -67.1       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 92          |
# |    time_elapsed         | 1298        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006168153 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.44        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 3.23        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 210.2078853046595
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -64         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 93          |
# |    time_elapsed         | 1311        |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006669267 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.09        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 3.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 210.80673758865248
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -60.4       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 94          |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005781304 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.71        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 3.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 211.34561403508772
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -57.7       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 95          |
# |    time_elapsed         | 1336        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.006228616 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0354     |
# |    value_loss           | 3.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 150.0
# Standard deviation of reward: 0.0
# Average successful assignments: 211.88107638888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 96          |
# |    time_elapsed         | 1350        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006939095 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.61        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 4.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 212.41580756013747
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 97           |
# |    time_elapsed         | 1362         |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0065033683 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.948        |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0352      |
# |    value_loss           | 3.19         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 212.94727891156464
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -49.6        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 98           |
# |    time_elapsed         | 1376         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0070138713 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.2          |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0363      |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 152.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.44949494949495
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -47          |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 99           |
# |    time_elapsed         | 1388         |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0062196855 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.47         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0333      |
# |    value_loss           | 3.32         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.96916666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -44.7        |
# | time/                   |              |
# |    fps                  | 73           |
# |    iterations           | 100          |
# |    time_elapsed         | 1402         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063697333 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.36         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.4          |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0359      |
# |    value_loss           | 3.36         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 64.94
# Overall Average Successful Assignments: 159.39046151895357

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -216.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.83333333333333
# All assignments history: [18, 20, 92, 92, 92, 92, 92, 92, 92, 92, 92, 92]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -362     |
# | time/              |          |
# |    fps             | 89       |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -348.0
# Standard deviation of reward: 0.0
# Average successful assignments: 51.791666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 2           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007593554 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.269      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.88        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 18.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -302.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.19444444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 3           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.007432618 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | 0.0249      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.76        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -342.0
# Standard deviation of reward: 0.0
# Average successful assignments: 43.604166666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 4           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007788424 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | 0.00483     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.58        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 9.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -310.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.833333333333336
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 5            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0073229074 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | 0.03         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.41         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 9.08         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -306.0
# Standard deviation of reward: 0.0
# Average successful assignments: 42.666666666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 6           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008043641 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.00327    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.39        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 8.48        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -240.0
# Standard deviation of reward: 0.0
# Average successful assignments: 46.464285714285715
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 7           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008162618 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | -0.00591    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.88        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0374     |
# |    value_loss           | 7.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 56.072916666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 8           |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008743939 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | -0.00905    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.32        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 5.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -144.0
# Standard deviation of reward: 0.0
# Average successful assignments: 62.092592592592595
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 9           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.008735389 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.00375     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.36        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 5.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.05
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 10          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010382418 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | 9.34e-05    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.644       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 73.91666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 11          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.011274867 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.0026      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.249       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 3.59        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 79.00694444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 12          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012784505 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00636     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.932       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0498     |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.46153846153847
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 13          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.011531789 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.0021      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.06        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 92.96428571428571
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 14          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016381111 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.000362    |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.00998    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.2388888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 15          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.014256739 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0072      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 4.95        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.61458333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 16          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013201738 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0418      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.5
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 17          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010513916 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.01        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 2.72        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.92129629629629
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 18          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008807583 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.298       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 119.83771929824562
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 19          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009520961 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.252       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 124.31666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 20          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010181518 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0829      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.1706349206349
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -357       |
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 21         |
# |    time_elapsed         | 274        |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.00958951 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.66      |
# |    explained_variance   | 0.223      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.55       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0448    |
# |    value_loss           | 2.97       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.77651515151516
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -355        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 22          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008729897 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.33        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 135.22826086956522
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 23          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.008889562 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.15        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.46875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 24          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007852094 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.66        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 141.33
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 25          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.007307277 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.238       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.28205128205127
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -347         |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 26           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0083454475 |
# |    clip_fraction        | 0.16         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.6          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0431      |
# |    value_loss           | 2.93         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.74074074074073
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 27          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007962991 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.08        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.08928571428572
# All assignments history: []
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 400      |
# |    ep_rew_mean          | -344     |
# | time/                   |          |
# |    fps                  | 78       |
# |    iterations           | 28       |
# |    time_elapsed         | 364      |
# |    total_timesteps      | 28672    |
# | train/                  |          |
# |    approx_kl            | 0.008875 |
# |    clip_fraction        | 0.165    |
# |    clip_range           | 0.15     |
# |    entropy_loss         | -5.42    |
# |    explained_variance   | 0.349    |
# |    learning_rate        | 0.00018  |
# |    loss                 | 0.42     |
# |    n_updates            | 270      |
# |    policy_gradient_loss | -0.0443  |
# |    value_loss           | 2.87     |
# --------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.19252873563218
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 29          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.009132069 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.517       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.19166666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -340         |
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 30           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0077963388 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.31        |
# |    explained_variance   | 0.381        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.49         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0425      |
# |    value_loss           | 2.99         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.06720430107526
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 31          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.007860288 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.84895833333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -336        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 32          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006952876 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.57828282828282
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -334        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 33          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008668043 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.02        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.19607843137254
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -331         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 34           |
# |    time_elapsed         | 440          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0077815405 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.04        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.911        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0433      |
# |    value_loss           | 2.78         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 100.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.96666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 35          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008124348 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.592       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.73842592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 36          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008620279 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.693       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 108.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.42342342342343
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 37          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007250273 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.889       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.85        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.0328947368421
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -320         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 38           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0072089583 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.73        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.02         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0407      |
# |    value_loss           | 2.77         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.6559829059829
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -317        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 39          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.007585791 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.22        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 118.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.24166666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -315         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 40           |
# |    time_elapsed         | 516          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0075460416 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.993        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0417      |
# |    value_loss           | 3.36         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 126.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.8638211382114
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -312         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 41           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0067483913 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.53        |
# |    explained_variance   | 0.531        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.27         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0407      |
# |    value_loss           | 2.92         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 136.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.57142857142858
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 42          |
# |    time_elapsed         | 542         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008661952 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 3.58        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.22868217054264
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -304         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 43           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0072208922 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.37        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.976        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0438      |
# |    value_loss           | 3.01         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 176.8219696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -301        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 44          |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007909048 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.977       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 140.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.3740740740741
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -297         |
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 45           |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0073580975 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.11         |
# |    n_updates            | 440          |
# ...
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.5920542635659
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -72.4       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 86          |
# |    time_elapsed         | 931         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006070348 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.68        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.1235632183908
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -68.4       |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 87          |
# |    time_elapsed         | 935         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.005711948 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.6619318181818
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 88          |
# |    time_elapsed         | 939         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006993374 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.1816479400749
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -59.9       |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 89          |
# |    time_elapsed         | 944         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.006474789 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 154.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.68148148148148
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -56         |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 90          |
# |    time_elapsed         | 948         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007020833 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.51        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.16941391941393
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -52.7        |
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 91           |
# |    time_elapsed         | 952          |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 0.0065991185 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0371      |
# |    value_loss           | 3.56         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.66666666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 92          |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007398918 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.6         |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 3.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.15412186379928
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -46.9       |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 93          |
# |    time_elapsed         | 961         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006030474 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.43        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.65336879432624
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -43.9        |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 94           |
# |    time_elapsed         | 965          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0073257196 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.09        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.62         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0385      |
# |    value_loss           | 4.14         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.13245614035088
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -41.6       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 95          |
# |    time_elapsed         | 970         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.006596806 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.22        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0343     |
# |    value_loss           | 3.37        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.60677083333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 96          |
# |    time_elapsed         | 974         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006117455 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.36        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 3.62        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.07130584192439
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -37.1        |
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 97           |
# |    time_elapsed         | 978          |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0053373943 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.67         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0352      |
# |    value_loss           | 4.33         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 164.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.54421768707482
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.4        |
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 98           |
# |    time_elapsed         | 982          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0061486987 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.62         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0375      |
# |    value_loss           | 3.64         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.9983164983165
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -32         |
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 99          |
# |    time_elapsed         | 987         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.006961896 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.46        |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.415
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -30.7        |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 100          |
# |    time_elapsed         | 991          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0068715774 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.13        |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0341      |
# |    value_loss           | 3.46         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 87.22
# Overall Average Successful Assignments: 168.02001303711967

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -382.0
# Standard deviation of reward: 0.0
# Average successful assignments: 9.416666666666666
# All assignments history: [9, 14, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -377     |
# | time/              |          |
# |    fps             | 251      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -334.0
# Standard deviation of reward: 0.0
# Average successful assignments: 19.958333333333332
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0072409725 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.87        |
# |    explained_variance   | -0.231       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.64         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0403      |
# |    value_loss           | 18           |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -330.0
# Standard deviation of reward: 0.0
# Average successful assignments: 24.0
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008238443 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.0318     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.73        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -256.0
# Standard deviation of reward: 0.0
# Average successful assignments: 33.854166666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007926131 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.05        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0404     |
# |    value_loss           | 9.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -146.0
# Standard deviation of reward: 0.0
# Average successful assignments: 48.65
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.007731108 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | 0.0328      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.3         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 8.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 65.48611111111111
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008161329 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.00346    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.25        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 7.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.97619047619048
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008727106 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.0071     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 6.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -92.0
# Standard deviation of reward: 0.0
# Average successful assignments: 84.64583333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009157189 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.00592     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.17        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0406     |
# |    value_loss           | 5.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -84.0
# Standard deviation of reward: 0.0
# Average successful assignments: 90.24074074074075
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -366        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 9           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009222797 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | 0.0139      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 4.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 96.01666666666667
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -365       |
# | time/                   |            |
# |    fps                  | 239        |
# |    iterations           | 10         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01068825 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.81      |
# |    explained_variance   | 0.00974    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 2.07       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0443    |
# |    value_loss           | 4.13       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 101.3030303030303
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 11          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010843278 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00927     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.217       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 106.81944444444444
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 12          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010661791 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00744     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.905       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 110.53205128205128
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 13          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012166576 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00297     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.494       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.38690476190476
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -362       |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 14         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01747502 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.77      |
# |    explained_variance   | 0.00569    |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.22       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0532    |
# |    value_loss           | 2.85       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 116.15
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -361         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 15           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0143340705 |
# |    clip_fraction        | 0.264        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.76        |
# |    explained_variance   | 0.0131       |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.61         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0454      |
# |    value_loss           | 2.89         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.984375
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 16          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011821218 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0291     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 121.42156862745098
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 17          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.011067632 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.27        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.047      |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 123.63888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 18          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009713806 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.72       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.32        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -24.0
# Standard deviation of reward: 0.0
# Average successful assignments: 125.66666666666667
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -356      |
# | time/                   |           |
# |    fps                  | 237       |
# |    iterations           | 19        |
# |    time_elapsed         | 82        |
# |    total_timesteps      | 19456     |
# | train/                  |           |
# |    approx_kl            | 0.0097542 |
# |    clip_fraction        | 0.192     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.7      |
# |    explained_variance   | 0.187     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.64      |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.0484   |
# |    value_loss           | 2.87      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.5
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 20          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010183624 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.822       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 129.48809523809524
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 21          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.010515914 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.574       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.27272727272728
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 22          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009263939 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 133.08695652173913
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 23          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009696603 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.52        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.84027777777777
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 24          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007676522 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.89        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 6.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.52333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 25          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.009341272 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.65        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 26.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.50320512820514
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -344         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 26           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0073947757 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.392        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.08         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0424      |
# |    value_loss           | 2.88         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 34.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.35802469135803
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 27          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007977612 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.416       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.07142857142858
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -341         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 28           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0076744994 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.386        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.448        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0439      |
# |    value_loss           | 2.9          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.66379310344828
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 29          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008128451 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.73        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 145.24166666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 30          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008344864 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 32.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.7741935483871
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -334       |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 31         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 31744      |
# | train/                  |            |
# |    approx_kl            | 0.00678769 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.22      |
# |    explained_variance   | 0.428      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.68       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0407    |
# |    value_loss           | 3.08       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.29166666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 32          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006942813 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.14       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.72        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 3.22        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 50.0
# Standard deviation of reward: 0.0
# Average successful assignments: 149.94444444444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 33          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.007571924 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.845       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.44607843137254
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -326         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 34           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0073706694 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.97        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.717        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0412      |
# |    value_loss           | 3.19         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 60.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.02142857142857
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 35          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008541864 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.86       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.6         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0485     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.6435185185185
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -320         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 36           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074795503 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.26         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0454      |
# |    value_loss           | 3.32         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.1216216216216
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -317        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 37          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.008436613 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.04        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0497     |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 157.6469298245614
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -313       |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 38         |
# |    time_elapsed         | 163        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00769329 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.56      |
# |    explained_variance   | 0.557      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.811      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0438    |
# |    value_loss           | 2.87       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 159.23504273504273
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -310         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 39           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0077975434 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.49        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.55         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.045       |
# |    value_loss           | 2.82         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.75
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -306        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 40          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008315692 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.742       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.1727642276423
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -302        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 41          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008204207 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.41        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.609126984127
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -299         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 42           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0072148745 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.1          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0392      |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.1375968992248
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 43          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.008408692 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 3.44        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 120.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.82575757575756
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 44          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008529162 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.897       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 124.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.46666666666667
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -289         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 45           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0076511763 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.12         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0431      |
# |    value_loss           | 3.05         |
# ...
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 212.43701550387595
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -66.4        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 86           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0056314263 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.02         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0329      |
# |    value_loss           | 2.89         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.08620689655172
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -62.3        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 87           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0064641107 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.12        |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.49         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.0342      |
# |    value_loss           | 3.28         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.72253787878788
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -58.5       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 88          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005530418 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 3.36        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 214.3614232209738
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -54.7        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 89           |
# |    time_elapsed         | 382          |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0065841656 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.21         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0382      |
# |    value_loss           | 3.37         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 214.96481481481482
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -51.4      |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 90         |
# |    time_elapsed         | 386        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00578739 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.506      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.03       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.033     |
# |    value_loss           | 3.31       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 166.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.55128205128204
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 91          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.006281822 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 3.43        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.14221014492753
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -45.2      |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 92         |
# |    time_elapsed         | 395        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00634232 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.14       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0362    |
# |    value_loss           | 2.93       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.7231182795699
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -42        |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 93         |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 95232      |
# | train/                  |            |
# |    approx_kl            | 0.00798932 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.508      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.42       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0368    |
# |    value_loss           | 3.23       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.30230496453902
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -39.3       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 94          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007435982 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.34        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 3.24        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 168.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.86315789473684
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -36.6      |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 95         |
# |    time_elapsed         | 408        |
# |    total_timesteps      | 97280      |
# | train/                  |            |
# |    approx_kl            | 0.00764683 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.52       |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.48       |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0357    |
# |    value_loss           | 3.08       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.41232638888889
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -34.4        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 96           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0067752264 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.25         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0373      |
# |    value_loss           | 3.56         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.9475945017182
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 97          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.007633906 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.02        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.4872448979592
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -29.5        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 98           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0065725287 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.39         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0375      |
# |    value_loss           | 2.86         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 170.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.00252525252526
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -27.1     |
# | time/                   |           |
# |    fps                  | 238       |
# |    iterations           | 99        |
# |    time_elapsed         | 425       |
# |    total_timesteps      | 101376    |
# | train/                  |           |
# |    approx_kl            | 0.0062186 |
# |    clip_fraction        | 0.111     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -3.04     |
# |    explained_variance   | 0.609     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.08      |
# |    n_updates            | 980       |
# |    policy_gradient_loss | -0.0338   |
# |    value_loss           | 3         |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 172.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.53666666666666
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -25.1        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 100          |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0063839424 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.33         |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0381      |
# |    value_loss           | 3.25         |
# ------------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 78.88
# Overall Average Successful Assignments: 164.61420289055084

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -384.0
# Standard deviation of reward: 0.0
# Average successful assignments: 8.166666666666666
# All assignments history: [12, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -382     |
# | time/              |          |
# |    fps             | 255      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -286.0
# Standard deviation of reward: 0.0
# Average successful assignments: 29.375
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -372       |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.00726746 |
# |    clip_fraction        | 0.0642     |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.87      |
# |    explained_variance   | -0.105     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 3.97       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0377    |
# |    value_loss           | 20.3       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -366.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.055555555555557
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008148948 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | 0.009       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.75        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -366.0
# Standard deviation of reward: 0.0
# Average successful assignments: 22.8125
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -374         |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068912897 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.86        |
# |    explained_variance   | -0.0165      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.28         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0363      |
# |    value_loss           | 11.3         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -318.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.733333333333334
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -371         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0066518234 |
# |    clip_fraction        | 0.0885       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.85        |
# |    explained_variance   | -0.0158      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.91         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 10.4         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -212.0
# Standard deviation of reward: 0.0
# Average successful assignments: 35.0
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -370         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 6            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0075894087 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | -0.0244      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.53         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0372      |
# |    value_loss           | 8.01         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 49.083333333333336
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.008744357 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.69        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.04       |
# |    value_loss           | 6.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -82.0
# Standard deviation of reward: 0.0
# Average successful assignments: 59.885416666666664
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -369        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 8           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008636063 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.006       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.34        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 6.19        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 69.74074074074075
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -368      |
# | time/                   |           |
# |    fps                  | 239       |
# |    iterations           | 9         |
# |    time_elapsed         | 38        |
# |    total_timesteps      | 9216      |
# | train/                  |           |
# |    approx_kl            | 0.0095053 |
# |    clip_fraction        | 0.17      |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.81     |
# |    explained_variance   | 0.00952   |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.2       |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.0402   |
# |    value_loss           | 5.02      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 77.95
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 10          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010195531 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00907     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.23        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 4.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -10.0
# Standard deviation of reward: 0.0
# Average successful assignments: 86.03787878787878
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 11          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010149876 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.79       |
# |    explained_variance   | 0.00789     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.222       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 3.68        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 91.22916666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 12          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011369873 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.78       |
# |    explained_variance   | 0.00647     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0471     |
# |    value_loss           | 3.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 95.66666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -364        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 13          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.012262559 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00544     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.661       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0455     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -36.0
# Standard deviation of reward: 0.0
# Average successful assignments: 99.98809523809524
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015484902 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00826     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.14        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.049      |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 104.83888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 15          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.014036074 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.0165      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.48        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 109.77604166666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 16          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010768689 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0772      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 30.0
# Standard deviation of reward: 0.0
# Average successful assignments: 114.13725490196079
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 17          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010832688 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0981      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.24537037037037
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 18          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009425357 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.67        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0426     |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 122.01754385964912
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -356         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 19           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0080318265 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.793        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0387      |
# |    value_loss           | 2.58         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 125.62083333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 20          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008726105 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.314       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0421     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 128.734126984127
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 21          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008483817 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.659       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.70833333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 22          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008160284 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.477       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.27173913043478
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -351         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 23           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0077377483 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.25         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.041       |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 136.68055555555554
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 24          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008897424 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.412       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 138.90333333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -348        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 25          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.008692083 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.587       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 40.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.91346153846155
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -346       |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 26         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00883133 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.5       |
# |    explained_variance   | 0.292      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 0.801      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0449    |
# |    value_loss           | 3.12       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 142.89814814814815
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -344        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 27          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.009133907 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.04        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 144.74107142857142
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 28          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008110515 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.16        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 48.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.5287356321839
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -340         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 29           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0093760155 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.355        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.34         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0479      |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.2722222222222
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -338        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 30          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007695902 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.0215053763441
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -336      |
# | time/                   |           |
# |    fps                  | 238       |
# |    iterations           | 31        |
# |    time_elapsed         | 133       |
# |    total_timesteps      | 31744     |
# | train/                  |           |
# |    approx_kl            | 0.0091121 |
# |    clip_fraction        | 0.172     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.27     |
# |    explained_variance   | 0.443     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 1.13      |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.049    |
# |    value_loss           | 2.81      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 151.72916666666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -334        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 32          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008052325 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.08        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 153.39141414141415
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -331         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 33           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0081266295 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.12        |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.871        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0454      |
# |    value_loss           | 3.07         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 154.95098039215685
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -328        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 34          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007497576 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.45        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 78.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.65
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 35          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.008460047 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.41        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 3.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 90.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.38425925925927
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -322        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 36          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007872852 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.05        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 3.31        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.12387387387386
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -319        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 37          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007880278 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 3.08        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 161.77850877192984
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 38          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007262012 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.28        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 3.33        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 108.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.46153846153845
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 39          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008273691 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.638       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 98.0
# Standard deviation of reward: 0.0
# Average successful assignments: 164.975
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -311        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 40          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008450622 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.839       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0463     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.5589430894309
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -307        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 41          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008566292 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.21        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 110.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.0595238095238
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -305       |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 42         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00796662 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -4.48      |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.43       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0445    |
# |    value_loss           | 3.12       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 114.0
# Standard deviation of reward: 0.0
# Average successful assignments: 169.5891472868217
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -301         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 43           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0077225077 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.04         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0422      |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 116.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.11742424242425
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -298        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 44          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008453861 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.977       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 122.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.65555555555557
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -294         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 45           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0062821694 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.38         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0399      |
# |    value_loss           | 3.58         |
# ------------------------------------------
# ...
# Standard deviation of reward: 0.0
# Average successful assignments: 212.26841085271317
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -78.6       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 86          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007050873 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 212.86206896551724
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -74.5        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 87           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 89088        |
# | train/                  |              |
# |    approx_kl            | 0.0073154005 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.23        |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.34         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.038       |
# |    value_loss           | 2.77         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.42992424242425
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -71          |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 88           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0065259947 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.11         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.0394      |
# |    value_loss           | 2.72         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 213.98876404494382
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -67.2       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 89          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.008162099 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.19        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 156.0
# Standard deviation of reward: 0.0
# Average successful assignments: 214.5388888888889
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -63.5        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 90           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0057142414 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.921        |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0361      |
# |    value_loss           | 2.83         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.07967032967034
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -60.6       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 91          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.007447053 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0402     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 215.6105072463768
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -57.2       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 92          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007474773 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.952       |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0394     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.13440860215053
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -54.2       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 93          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.008087374 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.66046099290782
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -51.5        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 94           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0071609206 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.29        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.19         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0395      |
# |    value_loss           | 3.03         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.14385964912282
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -49.8        |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 95           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0064993864 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.28        |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.928        |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0391      |
# |    value_loss           | 2.94         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.64756944444446
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -47.3       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 96          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007829984 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.1262886597938
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -45.2       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 97          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.006830532 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.891       |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.59948979591837
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -43         |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 98          |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007841796 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.4         |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.06734006734007
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -40.9       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 99          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 101376      |
# | train/                  |             |
# |    approx_kl            | 0.007028943 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.953       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.53833333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -38.7       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 100         |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008302735 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 78.5
# Overall Average Successful Assignments: 163.4623317753722

# %%
import pandas as pd
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

# Load datasets
tasks_df = pd.read_csv('RandomTasks400.csv')


# Rename columns for consistency
tasks_df.rename(columns={
    'Required_RAM': 'RAM',
    'Required_Storage': 'storage',
    'Minimum_Trust_Factor': 'Trustfactor',
    'Max_Distance': 'Distance',
    'Min_Transmission_Rate': 'TransmissionRate',
    'Min_Eligibility': 'MinEligibility'
}, inplace=True)

# Define the Gym environment for task allocation
class TaskAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, vehicles, tasks):
        super(TaskAllocationEnv, self).__init__()
        self.vehicles = vehicles
        self.tasks = tasks
        self.current_task = 0
        self.successful_assignments = 0
        self.successful_history = []  # Added to track successful assignments
        self.seed()

        num_features = tasks.shape[1]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(num_features,), dtype=np.float32)
        self.eligible_vehicle_indices = []
        self.update_action_space()

    def seed(self, seed=42):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]        
        
    def update_action_space(self):
        task_eligibility = self.tasks.iloc[self.current_task]['MinEligibility']
        eligible_vehicles = self.vehicles[self.vehicles['Eligible'] >= task_eligibility]
        self.eligible_vehicle_indices = eligible_vehicles.index.tolist()
        if len(self.eligible_vehicle_indices) == 0:
            self.action_space = spaces.Discrete(1)  # Prevents invalid action space of size 0
        else:
            self.action_space = spaces.Discrete(len(self.eligible_vehicle_indices))

    def reset(self):
        self.current_task = 0
        self.successful_assignments = 0
        self.update_action_space()
        #print("Resetting environment. Starting new episode.")
        return self.tasks.iloc[self.current_task].values.astype(np.float32)

    def step(self, action):
        task = self.tasks.iloc[self.current_task]
        vehicle = self.vehicles.iloc[action]
        reward = 0

        # Check if the vehicle meets all the task requirements
        meets_requirements = (
            vehicle['RAM'] >= task['RAM'] and
            vehicle['storage'] >= task['storage'] and
            vehicle['Trustfactor'] >= task['Trustfactor'] and
            vehicle['Distance'] <= task['Distance'] and
            vehicle['TransmissionRate'] >= task['TransmissionRate']
        )
        reward = 1 if meets_requirements else -1

        self.successful_assignments += reward > 0
        self.current_task += 1
        done = self.current_task >= len(self.tasks)

        if not done:
            self.update_action_space()
            next_state = self.tasks.iloc[self.current_task].values.astype(np.float32)
        else:
            next_state = np.zeros(self.observation_space.shape[0])
            self.successful_history.append(self.successful_assignments)
            #print(f"Episode completed. Successful assignments: {self.successful_assignments}.")
            self.successful_assignments = 0  # Reset for next episode

        
        
        #three lines below can be uncommented for more detailed output
        #print(f"Task Details: {task.to_dict()}")
        #print(f"Vehicle Details: {vehicle.to_dict()}")
        #print(f"Step: Task {self.current_task}, Action {action}, Reward {reward}")

        return next_state, reward, done, {}

    def get_average_success(self):
        return np.mean(self.successful_history) if self.successful_history else 0


    def render(self, mode='human'):
        pass

    def close(self):
        pass



# Custom callback for logging
class CustomCallback(BaseCallback):
    def __init__(self, env, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.env = env
        self.total_rewards = 0
        self.total_assignments = 0
        self.num_episodes = 0

    def _on_step(self):
        return True

    def _on_rollout_end(self):
        mean_reward, std_reward = evaluate_policy(self.model, self.model.get_env(), n_eval_episodes=10)
        average_assignments = self.env.get_attr('get_average_success')[0]()
        self.total_rewards += mean_reward
        self.total_assignments += average_assignments
        self.num_episodes += 1

        print("-------- Rollout Summary --------")
        print(f"Total mean reward: {mean_reward}")
        print(f"Standard deviation of reward: {std_reward}")
        print(f"Average successful assignments: {average_assignments}")
        print("All assignments history:", self.env.envs[0].successful_history)
        self.env.envs[0].successful_history = []  # Reset history after each iteration

    def _on_training_end(self):
        average_total_reward = self.total_rewards / self.num_episodes
        average_total_assignments = self.total_assignments / self.num_episodes
        print("-------- Training Summary --------")
        print(f"Overall Average Mean Reward: {average_total_reward}")
        print(f"Overall Average Successful Assignments: {average_total_assignments}")


# Prepare the environment
env = make_vec_env(lambda: TaskAllocationEnv(vehicles_df, tasks_df), n_envs=1)

# Initialize and train the PPO model
model = PPO("MlpPolicy", env, verbose=1,
            n_steps=1024, batch_size=128, n_epochs=10, learning_rate=0.00018,
            gamma=0.96, gae_lambda=0.87, clip_range=0.15, ent_coef=0.07)

callback = CustomCallback(env)  # Use custom callback for detailed tracking and logging

# Train the model with the custom callback
model.learn(total_timesteps=1024*100, callback=callback)

# Save the model
model.save("ppo_task_allocation_model")
# Out:
# Using cpu device
# C:\Users\asdra\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# -------- Rollout Summary --------
# Total mean reward: -370.0
# Standard deviation of reward: 0.0
# Average successful assignments: 15.0
# All assignments history: [18, 12, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15]
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -370     |
# | time/              |          |
# |    fps             | 245      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.get_average_success to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_average_success` for environment variables or `env.get_wrapper_attr('get_average_success')` that will search the reminding wrappers.
#   logger.warn(
# C:\Users\asdra\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.successful_history to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.successful_history` for environment variables or `env.get_wrapper_attr('successful_history')` that will search the reminding wrappers.
#   logger.warn(
# -------- Rollout Summary --------
# Total mean reward: -318.0
# Standard deviation of reward: 0.0
# Average successful assignments: 25.625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007885432 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.87       |
# |    explained_variance   | -0.247      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.43        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0404     |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -138.0
# Standard deviation of reward: 0.0
# Average successful assignments: 54.138888888888886
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -374        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.007443699 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.86       |
# |    explained_variance   | -0.144      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.85        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -180.0
# Standard deviation of reward: 0.0
# Average successful assignments: 64.10416666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -373        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008216925 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.85       |
# |    explained_variance   | 0.0302      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.27        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0396     |
# |    value_loss           | 10.4        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -206.0
# Standard deviation of reward: 0.0
# Average successful assignments: 67.98333333333333
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -372         |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0089694075 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.84        |
# |    explained_variance   | -0.0071      |
# |    learning_rate        | 0.00018      |
# |    loss                 | 2.23         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0393      |
# |    value_loss           | 9.05         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -188.0
# Standard deviation of reward: 0.0
# Average successful assignments: 71.83333333333333
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -371        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008613978 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.84       |
# |    explained_variance   | -0.0089     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.07        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 7.56        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -42.0
# Standard deviation of reward: 0.0
# Average successful assignments: 83.30952380952381
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009046502 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.83       |
# |    explained_variance   | 0.00192     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.77        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 6.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -96.0
# Standard deviation of reward: 0.0
# Average successful assignments: 89.1875
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009624295 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.82       |
# |    explained_variance   | -0.00418    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.07        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 5.5         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 94.91666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -368        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 9           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.010373008 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.81       |
# |    explained_variance   | -0.00857    |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.09        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 4.46        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: -8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 102.075
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 10          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010379191 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.00504     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.435       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 2.0
# Standard deviation of reward: 0.0
# Average successful assignments: 108.39393939393939
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -366       |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 11         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.01016145 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -5.79      |
# |    explained_variance   | 0.0087     |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.67       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0387    |
# |    value_loss           | 3.62       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 8.0
# Standard deviation of reward: 0.0
# Average successful assignments: 113.82638888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -365        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 12          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011494661 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.77       |
# |    explained_variance   | 0.00703     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 3.12        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 4.0
# Standard deviation of reward: 0.0
# Average successful assignments: 118.41666666666667
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -363        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.013351706 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.76       |
# |    explained_variance   | 0.00647     |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.138       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 28.0
# Standard deviation of reward: 0.0
# Average successful assignments: 122.98214285714286
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -362        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016843028 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.75       |
# |    explained_variance   | 0.0164      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.012       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0502     |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 38.0
# Standard deviation of reward: 0.0
# Average successful assignments: 127.28888888888889
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -361        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 15          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.010855204 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.0579      |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.0876      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 44.0
# Standard deviation of reward: 0.0
# Average successful assignments: 131.21354166666666
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -359        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 16          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011579788 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.33        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 134.69117647058823
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -358        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 17          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.010154716 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.717       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 2.9         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 46.0
# Standard deviation of reward: 0.0
# Average successful assignments: 137.8148148148148
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -357        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 18          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010905644 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.695       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 54.0
# Standard deviation of reward: 0.0
# Average successful assignments: 140.82894736842104
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 19          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.011014199 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.181       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 2.66        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 58.0
# Standard deviation of reward: 0.0
# Average successful assignments: 143.65
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 20          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010186636 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2.72        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.13        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 52.0
# Standard deviation of reward: 0.0
# Average successful assignments: 146.0515873015873
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -353         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 21           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0094306525 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.6          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0452      |
# |    value_loss           | 3.17         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 56.0
# Standard deviation of reward: 0.0
# Average successful assignments: 148.39772727272728
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 22          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009558853 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 2           |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 3           |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 150.80434782608697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 23          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009362953 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.34        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 152.99652777777777
# All assignments history: []
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -347      |
# | time/                   |           |
# |    fps                  | 234       |
# |    iterations           | 24        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0088022 |
# |    clip_fraction        | 0.146     |
# |    clip_range           | 0.15      |
# |    entropy_loss         | -5.47     |
# |    explained_variance   | 0.326     |
# |    learning_rate        | 0.00018   |
# |    loss                 | 2.26      |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0411   |
# |    value_loss           | 2.89      |
# ---------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 155.01333333333332
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 25          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.008993847 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.2         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 3.06        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 156.86858974358975
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -343         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 26           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0071554002 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.693        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0382      |
# |    value_loss           | 3.16         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 158.69135802469137
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -340        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 27          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.007831334 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.35        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 160.44940476190476
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -337         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 28           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0071529024 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.06         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0383      |
# |    value_loss           | 3.04         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 68.0
# Standard deviation of reward: 0.0
# Average successful assignments: 162.07183908045977
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -334         |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 29           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0073960274 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -5.14        |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.988        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0397      |
# |    value_loss           | 3.18         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 66.0
# Standard deviation of reward: 0.0
# Average successful assignments: 163.59444444444443
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -331        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 30          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008181021 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.862       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 165.11559139784947
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 31          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.008420735 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.985       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 70.0
# Standard deviation of reward: 0.0
# Average successful assignments: 166.5390625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 32          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008473569 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.88       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.746       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.16        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 62.0
# Standard deviation of reward: 0.0
# Average successful assignments: 167.78030303030303
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -321        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 33          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.009070985 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.02        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 64.0
# Standard deviation of reward: 0.0
# Average successful assignments: 168.9950980392157
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 34          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007936343 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.27        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 72.0
# Standard deviation of reward: 0.0
# Average successful assignments: 170.2595238095238
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -314        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 35          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.007512805 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.854       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 2.92        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 74.0
# Standard deviation of reward: 0.0
# Average successful assignments: 171.48842592592592
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -311        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 36          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008415008 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.14        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 76.0
# Standard deviation of reward: 0.0
# Average successful assignments: 172.69594594594594
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -308        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 37          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.007105327 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.39        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 80.0
# Standard deviation of reward: 0.0
# Average successful assignments: 173.94736842105263
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -304        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 38          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008131107 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 88.0
# Standard deviation of reward: 0.0
# Average successful assignments: 175.23931623931625
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -300        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 39          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008526595 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.14        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0407     |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 176.42708333333334
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 40          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007481913 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.06        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 86.0
# Standard deviation of reward: 0.0
# Average successful assignments: 177.5670731707317
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -293        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 41          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.008120244 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.42        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 3.57        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 178.7718253968254
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -289        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 42          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008980411 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.1         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 2.75        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 94.0
# Standard deviation of reward: 0.0
# Average successful assignments: 179.89728682170542
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -285        |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 43          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009136565 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.681       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 102.0
# Standard deviation of reward: 0.0
# Average successful assignments: 181.0719696969697
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -282        |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 44          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008271565 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.03        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0455     |
# |    value_loss           | 3.03        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 106.0
# Standard deviation of reward: 0.0
# Average successful assignments: 182.25925925925927
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -278        |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 45          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.007109951 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.12        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 3.11        |
# ...
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 216.54748062015503
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -63.1       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 86          |
# |    time_elapsed         | 377         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005759048 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.47        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 3.84        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.1197318007663
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -59.5       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 87          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.006470881 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.892       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 217.68939393939394
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -56.4       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 88          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006047207 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.25        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.2453183520599
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -53.5        |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 89           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 91136        |
# | train/                  |              |
# |    approx_kl            | 0.0058765765 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.08         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.0367      |
# |    value_loss           | 2.85         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 218.7962962962963
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -50.3        |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 90           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0060931873 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0.348        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 0.939        |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0386      |
# |    value_loss           | 2.96         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.32234432234432
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -47.5       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 91          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.007021618 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.52        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 2.94        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 219.84329710144928
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -44.7       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 92          |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005926331 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.18        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0386     |
# |    value_loss           | 3.4         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 162.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.33870967741936
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -42.2       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 93          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.006123824 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 0.991       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 220.8218085106383
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -39.6       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 94          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006192701 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.11        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 160.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.30789473684212
# All assignments history: []
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -37.2       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 95          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.005794287 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.00018     |
# |    loss                 | 1.24        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 221.79947916666666
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -34        |
# | time/                   |            |
# |    fps                  | 235        |
# |    iterations           | 96         |
# |    time_elapsed         | 417        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00779563 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.1        |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0362    |
# |    value_loss           | 2.66       |
# ----------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.26374570446737
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -31.3        |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 97           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 99328        |
# | train/                  |              |
# |    approx_kl            | 0.0068872375 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 0.459        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.01         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.0374      |
# |    value_loss           | 2.89         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 222.718537414966
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -28.8        |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 98           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0068844287 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.19         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0351      |
# |    value_loss           | 3.15         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.15740740740742
# All assignments history: []
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -26.9        |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 99           |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 101376       |
# | train/                  |              |
# |    approx_kl            | 0.0064110523 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.467        |
# |    learning_rate        | 0.00018      |
# |    loss                 | 1.16         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.0388      |
# |    value_loss           | 3.27         |
# ------------------------------------------
# -------- Rollout Summary --------
# Total mean reward: 158.0
# Standard deviation of reward: 0.0
# Average successful assignments: 223.59833333333333
# All assignments history: []
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -24.6      |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 100        |
# |    time_elapsed         | 433        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00669597 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.00018    |
# |    loss                 | 1.79       |
# |    n_updates            | 990        |
# |    policy_gradient_loss | -0.0352    |
# |    value_loss           | 3.7        |
# ----------------------------------------
# -------- Training Summary --------
# Overall Average Mean Reward: 85.24
# Overall Average Successful Assignments: 174.7091130059394
